# %%
# !pip install eotdl
# Out:
# ...
#   Obtaining dependency information for eotdl from https://files.pythonhosted.org/packages/85/c4/8857c09dd3de1da10a9ab2cde8482758795c8bea9b2620b7e169cba8c5ba/eotdl-2024.5.2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for black<24.0.0,>=23.10.1 from https://files.pythonhosted.org/packages/40/fe/658c1cb463adcd9f34d3b2d89007d576e9f2007d22c70c95700f95ee4a5e/black-23.12.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 555.4 kB/s eta 0:00:00 0:00:01
# ...
#   Obtaining dependency information for geomet<2.0.0,>=1.0.0 from https://files.pythonhosted.org/packages/af/90/3bc780df088d439714af8295196a4332a26559ae66fd99865e36f92efa9e/geomet-1.1.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for geopandas<0.14.0,>=0.13.2 from https://files.pythonhosted.org/packages/cb/7b/2fb6ab376c78d2e60812ad0bf4b24889309d2aeb543f54efcd586c69907f/geopandas-0.13.2-py3-none-any.whl.metadata
# ...

# %%
# !eotdl datasets get AI4EO-MapYourCity
# Out:
# On your computer or mobile device navigate to:  https://earthpulse.eu.auth0.com/activate?user_code=MJMH-PKVV
# ^C
#
# Aborted.
