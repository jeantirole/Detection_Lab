# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import json

# %%
log_list = os.listdir("./01.log")
print(sorted(log_list))
log_ = sorted(log_list)[-1]
log_ = "/mnt/hdd/eric/.tmp_ipy/15.Lab_Detection/05.Tasks/ObjectDetection/01.log/ver_21_2024-04-15_17-18-38.log"
f = open(os.path.join("./01.log", log_))
lines = f.readlines()
print(log_)
# Out:
# ['ver_21_2024-04-15_17-17-26.log', 'ver_21_2024-04-15_17-18-38.log', 'ver_6_2024-04-15_00-16-32.log', 'ver_6_2024-04-15_00-17-23.log', 'ver_7_2024-04-15_00-19-35.log', 'ver_8_2024-04-15_11-14-45.log', 'ver_8_2024-04-15_16-11-01.log']
# /mnt/hdd/eric/.tmp_ipy/15.Lab_Detection/05.Tasks/ObjectDetection/01.log/ver_21_2024-04-15_17-18-38.log

# %%
json_object = json.loads( lines[0].replace("\n","").replace("'", '"') )
print(json_object)
# Out:
# {'epoch': 0, 'iteration': 0, 'loss': '3.32328', 'lr': 0.005}

# %%
from collections import defaultdict
log_dict = defaultdict(list)

for line in lines:
    json_object = json.loads( line.replace("\n","").replace("'", '"') )
    for key in json_object:
        log_dict[key].append(json_object[key])

# %%
losses = [float(i) for i in log_dict['loss'] if float(i) < 400]
# Plot loss over time
plt.figure(figsize=(14, 10))
plt.plot(losses, marker='o', linestyle='-')
plt.title('Loss over Time')
plt.xlabel('Iterations')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
dices = [float(i) for i in log_dict['dice']]
# Plot loss over time
plt.figure(figsize=(14, 10))
plt.plot(dices, marker='o', linestyle='-',color='green')
plt.title('Dice over Time')
plt.xlabel('Iterations')
plt.ylabel('Dice')
# Out:
# Text(0, 0.5, 'Dice')

# %%
dices = [float(i) for i in log_dict['lr']]
# Plot loss over time
plt.figure(figsize=(14, 10))
plt.plot(dices, marker='o', linestyle='-',color='green')
plt.title('Learning Rate over Time')
plt.xlabel('Iterations')
plt.ylabel('LR')
# Out:
# Text(0, 0.5, 'LR')
