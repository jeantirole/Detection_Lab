# %%
import sys 
sys.path.append("/mnt/hdd/eric/.tmp_ipy/15.Lab_Detection/00.Libs")
import RS_dataset
import RS_models
import RS_utils

from PIL import Image, ImageDraw, ImageFont
import os
import numpy as np 
import matplotlib.pyplot as plt
import cv2
import torch 
from typing import Dict, Any, List
import numpy as np
from PIL import Image
import xml.etree.ElementTree as ET
import collections
from glob import glob
from matplotlib.patches import Polygon
# Out:
# /mnt/hdd/eric/.conda/envs/a.samrs/lib/python3.8/site-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.18) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
#-- data 
images_path = "/mnt/hdd/eric/.tmp_ipy/00.Data/DOTA_dataset/dota1_ms_train/images"
anno_path = "/mnt/hdd/eric/.tmp_ipy/00.Data/DOTA_dataset/dota1_ms_train/annfiles"

# %%
img_list = sorted(glob(os.path.join(images_path, "*.png")))
anno_list = sorted(glob(os.path.join(anno_path, "*.txt")))

print(img_list[0:2])
# Out:
# ['/mnt/hdd/eric/.tmp_ipy/00.Data/DOTA_dataset/dota1_ms_train/images/P0000__1024__0___0.png', '/mnt/hdd/eric/.tmp_ipy/00.Data/DOTA_dataset/dota1_ms_train/images/P0000__1024__0___1048.png']

# %%
len(img_list), len(anno_list)
# Out:
# (103421, 103421)

# %%
idx = 12

img = Image.open(img_list[idx])
lines = RS_utils.read_txt(anno_list[idx])

# %%
fig,ax = plt.subplots(figsize=(18,18))

for line in lines:
    bbox = [float(i) for i in line.split(" ")[0:8]]
    bbox_ar = np.array( [ [bbox[0],bbox[1]],[bbox[2],bbox[3]],[bbox[4],bbox[5]],[bbox[6],bbox[7]] ] )
    p = Polygon(bbox_ar, facecolor = 'r', fill=True, alpha=0.5, linewidth=3)
    ax.add_patch(p)

plt.imshow(img)

# %%
len(lines)
# Out:
# 64
