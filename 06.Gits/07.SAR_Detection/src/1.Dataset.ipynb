# %%
import os

# %%
os.listdir("/mnt/hdd/eric/.tmp_ipy/00.Data/SAR/images")
# Out:
# ['P0060_1800_2600_1800_2600.png',
#  'P0030_2400_3200_3600_4400.png',
#  'P0044_1800_2600_600_1400.png',
#  'P0013_3000_3800_0_800.png',
#  'P0053_600_1400_4800_5600.png',
#  'P0031_1800_2600_7800_8600.png',
#  'P0063_4200_5000_3600_4400.png',
#  'P0080_3000_3800_3000_3800.png',
#  'P0005_1200_2000_3600_4400.png',
#  'P0043_2400_3200_3000_3800.png',
#  'P0002_0_800_8689_9489.png',
#  'P0087_0_800_2400_3200.png',
#  'P0037_1800_2600_6000_6800.png',
#  'P0071_3000_3800_3600_4400.png',
#  'P0077_600_1400_4200_5000.png',
#  'P0041_1200_2000_3600_4400.png',
#  'P0067_2400_3200_4800_5600.png',
#  'P0058_2400_3200_3600_4400.png',
#  'P0019_4800_5600_2400_3200.png',
#  'P0034_1200_2000_8400_9200.png',
#  'P0031_2400_3200_3000_3800.png',
#  'P0091_600_1400_600_1400.png',
#  'P0029_5400_6200_4800_5600.png',
#  'P0037_4200_5000_6000_6800.png',
#  'P0070_0_800_5400_6200.png',
#  'P0089_2200_3000_600_1400.png',
#  'P0014_4560_5360_600_1400.png',
#  'P0006_4762_5562_6600_7400.png',
# ...

# %%
from PIL import Image
import numpy as np

data_root = "/mnt/hdd/eric/.tmp_ipy/00.Data/SAR/"
img_prefix = "images"
img_paths = [os.path.join(data_root, img_prefix,i) for i in os.listdir("/mnt/hdd/eric/.tmp_ipy/00.Data/SAR/images")]

# %%
idx = 0 
img = img_paths[idx]
img_ = Image.open(img)

# %%
img_ = np.asarray(img_)

# %%
img_.shape
# Out:
# (800, 800, 3)

# %%
img_
# Out:
# array([[[23, 23, 23],
#         [12, 12, 12],
#         [ 6,  6,  6],
#         ...,
#         [19, 19, 19],
#         [13, 13, 13],
#         [10, 10, 10]],
#
#        [[15, 15, 15],
#         [ 9,  9,  9],
#         [22, 22, 22],
#         ...,
#         [12, 12, 12],
#         [12, 12, 12],
#         [28, 28, 28]],
#
#        [[16, 16, 16],
#         [12, 12, 12],
#         [ 5,  5,  5],
#         ...,
#         [13, 13, 13],
#         [27, 27, 27],
#         [15, 15, 15]],
#
#        ...,
#
#        [[33, 33, 33],
#         [40, 40, 40],
#         [20, 20, 20],
#         ...,
#         [15, 15, 15],
#         [38, 38, 38],
#         [27, 27, 27]],
#
#        [[25, 25, 25],
#         [20, 20, 20],
#         [13, 13, 13],
#         ...,
#         [33, 33, 33],
#         [38, 38, 38],
#         [14, 14, 14]],
#
#        [[32, 32, 32],
#         [18, 18, 18],
#         [11, 11, 11],
#         ...,
#         [16, 16, 16],
#         [20, 20, 20],
#         [25, 25, 25]]], dtype=uint8)

# %%
# inference set 을 어떤걸 구하면 좋을까 ~
# Out:
# array([[[23, 23, 23],
#         [12, 12, 12],
#         [ 6,  6,  6],
#         ...,
#         [19, 19, 19],
#         [13, 13, 13],
#         [10, 10, 10]],
#
#        [[15, 15, 15],
#         [ 9,  9,  9],
#         [22, 22, 22],
#         ...,
#         [12, 12, 12],
#         [12, 12, 12],
#         [28, 28, 28]],
#
#        [[16, 16, 16],
#         [12, 12, 12],
#         [ 5,  5,  5],
#         ...,
#         [13, 13, 13],
#         [27, 27, 27],
#         [15, 15, 15]],
#
#        ...,
#
#        [[33, 33, 33],
#         [40, 40, 40],
#         [20, 20, 20],
#         ...,
#         [15, 15, 15],
#         [38, 38, 38],
#         [27, 27, 27]],
#
#        [[25, 25, 25],
#         [20, 20, 20],
#         [13, 13, 13],
#         ...,
#         [33, 33, 33],
#         [38, 38, 38],
#         [14, 14, 14]],
#
#        [[32, 32, 32],
#         [18, 18, 18],
#         [11, 11, 11],
#         ...,
#         [16, 16, 16],
#         [20, 20, 20],
#         [25, 25, 25]]], dtype=uint8)
