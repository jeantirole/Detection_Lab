# %%
# %cd /mnt/hdd/eric/.tmp_ipy/15.Lab_Detection/06.Gits/05.OWOD/02.DOTA_Processing/DOTA_devkit
# Out:
# /mnt/hdd/eric/.tmp_ipy/15.Lab_Detection/06.Gits/05.OWOD/02.DOTA_Processing/DOTA_devkit

# %%
# !pwd
# Out:
# /mnt/hdd/eric/.tmp_ipy/15.Lab_Detection/06.Gits/05.OWOD/02.DOTA_Processing/DOTA_devkit

# %%
# %%bash
#
# python /mnt/hdd/eric/.tmp_ipy/15.Lab_Detection/06.Gits/05.OWOD/02.DOTA_Processing/DOTA_devkit/DOTA2COCO.py
# Out:
# 0 / 15749
# 1 / 15749
# 2 / 15749
# 3 / 15749
# 4 / 15749
# 5 / 15749
# 6 / 15749
# 7 / 15749
# 8 / 15749
# 9 / 15749
# 10 / 15749
# 11 / 15749
# 12 / 15749
# 13 / 15749
# 14 / 15749
# 15 / 15749
# 16 / 15749
# 17 / 15749
# 18 / 15749
# 19 / 15749
# 20 / 15749
# 21 / 15749
# 22 / 15749
# 23 / 15749
# 24 / 15749
# 25 / 15749
# 26 / 15749
# 27 / 15749
# 28 / 15749
# 29 / 15749
# 30 / 15749
# 31 / 15749
# 32 / 15749
# 33 / 15749
# 34 / 15749
# 35 / 15749
# 36 / 15749
# 37 / 15749
# 38 / 15749
# 39 / 15749
# 40 / 15749
# 41 / 15749
# 42 / 15749
# 43 / 15749
# 44 / 15749
# 45 / 15749
# 46 / 15749
# 47 / 15749
# 48 / 15749
# 49 / 15749
# 50 / 15749
# 51 / 15749
# 52 / 15749
# 53 / 15749
# 54 / 15749
# 55 / 15749
# 56 / 15749
# 57 / 15749
# 58 / 15749
# 59 / 15749
# 60 / 15749
# 61 / 15749
# 62 / 15749
# 63 / 15749
# 64 / 15749
# 65 / 15749
# 66 / 15749
# 67 / 15749
# 68 / 15749
# 69 / 15749
# 70 / 15749
# 71 / 15749
# 72 / 15749
# 73 / 15749
# 74 / 15749
# 75 / 15749
# 76 / 15749
# ...

# %%
# %%bash
#
# python /mnt/hdd/eric/.tmp_ipy/15.Lab_Detection/06.Gits/05.OWOD/02.DOTA_Processing/DOTA_devkit/DOTA2COCO.py
# Out:
# 0 / 5297
# 1 / 5297
# 2 / 5297
# 3 / 5297
# 4 / 5297
# 5 / 5297
# 6 / 5297
# 7 / 5297
# 8 / 5297
# 9 / 5297
# 10 / 5297
# 11 / 5297
# 12 / 5297
# 13 / 5297
# 14 / 5297
# 15 / 5297
# 16 / 5297
# 17 / 5297
# 18 / 5297
# 19 / 5297
# 20 / 5297
# 21 / 5297
# 22 / 5297
# 23 / 5297
# 24 / 5297
# 25 / 5297
# 26 / 5297
# 27 / 5297
# 28 / 5297
# 29 / 5297
# 30 / 5297
# 31 / 5297
# 32 / 5297
# 33 / 5297
# 34 / 5297
# 35 / 5297
# 36 / 5297
# 37 / 5297
# 38 / 5297
# 39 / 5297
# 40 / 5297
# 41 / 5297
# 42 / 5297
# 43 / 5297
# 44 / 5297
# 45 / 5297
# 46 / 5297
# 47 / 5297
# 48 / 5297
# 49 / 5297
# 50 / 5297
# 51 / 5297
# 52 / 5297
# 53 / 5297
# 54 / 5297
# 55 / 5297
# 56 / 5297
# 57 / 5297
# 58 / 5297
# 59 / 5297
# 60 / 5297
# 61 / 5297
# 62 / 5297
# 63 / 5297
# 64 / 5297
# 65 / 5297
# 66 / 5297
# 67 / 5297
# 68 / 5297
# 69 / 5297
# 70 / 5297
# 71 / 5297
# 72 / 5297
# 73 / 5297
# 74 / 5297
# 75 / 5297
# 76 / 5297
# 77 / 5297
# 78 / 5297
# 79 / 5297
# 80 / 5297
# 81 / 5297
# 82 / 5297
# 83 / 5297
# ...
