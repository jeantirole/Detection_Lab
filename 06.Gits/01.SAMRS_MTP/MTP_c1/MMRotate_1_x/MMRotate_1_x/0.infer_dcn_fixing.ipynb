# %%
# !mim install mmcv==2.0.0
import mmcv
mmcv.__version__
# Out:
# '2.0.0'

# %%
import mmengine
mmengine.__version__
# Out:
# '0.10.3'

# %%
#!mim install mmdet==3.1.0
import mmdet
mmdet.__version__
# Out:
# '3.1.0'

# %%
# !pwd

# %%
# !git clone https://github.com/open-mmlab/mmrotate.git -b dev-1.x

# %%
# %cd mmrotate

# %%
# !pip install -v -e .

# %%
import mmrotate
mmrotate.__version__
# Out:
# '1.0.0rc1'

# %%
import torch
torch.__version__
# Out:
# '1.10.0+cu111'

# %%
# !pip install /mnt/hdd/eric/.tmp_ipy/15.Lab_Detection/06.Gits/01.SAMRS_MTP/MTP/MMRotate_1_x/DCNv3-1.0+cu113torch1.11.0-cp38-cp38-linux_x86_64.whl --force-reinstall

# %%
# %cd /mnt/hdd/eric/.tmp_ipy/15.Lab_Detection/06.Gits/01.SAMRS_MTP/MTP/MMRotate_1_x/mmrotate
# Out:
# /mnt/hdd/eric/.tmp_ipy/15.Lab_Detection/06.Gits/01.SAMRS_MTP/MTP/MMRotate_1_x/mmrotate

# %%
# !ls
# Out:
# CITATION.cff  README_zh-CN.md  docs		  projects	    setup.cfg
# LICENSE       configs	       mmrotate		  requirements	    setup.py
# MANIFEST.in   demo	       mmrotate.egg-info  requirements.txt  tests
# README.md     docker	       model-index.yml	  resources	    tools

# %%
# %%bash
#
# CUDA_VISIBLE_DEVICES=0 python /mnt/hdd/eric/.tmp_ipy/15.Lab_Detection/06.Gits/01.SAMRS_MTP/MTP/MMRotate_1_x/mmrotate/tools/test.py \
#     /mnt/hdd/eric/.tmp_ipy/15.Lab_Detection/06.Gits/01.SAMRS_MTP/MTP/RS_Tasks_Finetune/Rotated_Detection/mmrotate1.x/configs/mtp/dotav2/oriented_rcnn_rvsa_l_1024_mae_mtp_dota20.py \
#     /mnt/hdd/eric/.tmp_ipy/00.Weights/MTP/diorr-rvsa-l-mae-mtp-epoch_12.pth \
# --work-dir=/mnt/hdd/eric/.tmp_ipy/15.Lab_Detection/06.Gits/01.SAMRS_MTP/MTP/MMRotate_1_x/work_dir \
# --show-dir=/mnt/hdd/eric/.tmp_ipy/15.Lab_Detection/06.Gits/01.SAMRS_MTP/MTP/MMRotate_1_x/show_dir
# Out:
# 04/22 14:07:40 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.17 (default, Jul  5 2023, 21:04:15) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1196561449
#     GPU 0: NVIDIA GeForce RTX 3090
#     CUDA_HOME: /usr/local/cuda-11.1
#     NVCC: Cuda compilation tools, release 11.1, V11.1.74
#     GCC: gcc (Ubuntu 8.4.0-3ubuntu2) 8.4.0
#     PyTorch: 1.10.0+cu111
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.1
# ...
