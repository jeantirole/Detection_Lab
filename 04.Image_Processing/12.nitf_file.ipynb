# %%
fpath = "/mnt/hdd/eric/.tmp_ipy/15.Lab_Detection/04.Image_Processing/Sample_data/2023-01-20-12-51-23_UMBRA-04_SIDD.png"

# %%
import matplotlib.pyplot as plt 
from PIL import Image

img = Image.open(fpath)
plt.figure(figsize=(20,20))
# plt.xticks(range(img.size[1]))
# plt.yticks(range(img.size[0]))
plt.grid()
plt.imshow(img)

# %%
import numpy as np
img_ = np.asarray(img)
a = img_[1000:1100,1000:1100]
plt.imshow(a)

# %%
PIL_image = Image.fromarray(np.uint8(a)).convert('L')

# %%
plt.imsave("/mnt/hdd/eric/.tmp_ipy/15.Lab_Detection/04.Image_Processing/Sample_data/umbra_ship_2.png", PIL_image,cmap='gray',dpi=800)
