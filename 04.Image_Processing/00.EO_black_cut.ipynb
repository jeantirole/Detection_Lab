# %%
#---------------------- Header 
from easydict import EasyDict
import os
import json
args = EasyDict()
from PIL import Image
import numpy as np 
Image.MAX_IMAGE_PIXELS = 933120000

# %%
#------ image list 

args.img_path = "/mnt/hdd/eric/.tmp_ipy/00.Data/AO/0-Pusan-2023-AO/C1_20221227015155_09806_00006119_L1G/0-Pusan-2023-AO_1_C1_20221227015155_09806_00006119_L1G.png"

# %%
# Draw image 
img_path = args.img_path
img_ = Image.open(img_path)

# %%
img_.size
# Out:
# (7410, 7220)

# %%
import matplotlib.pyplot as plt 

plt.figure(figsize=(10,10))
plt.imshow(img_)

# %%
# Sampling

# %%
a1 =[
    [1,2,3,4,5,6,7],
    [4,5,6,1,2,3,4],
    [4,5,6,1,2,3,4]
]

# %%
len(a1[0])
# Out:
# 7

# %%
# if window size 2 
window_size = 4

padding_size = window_size - len(a1[0]) % window_size

# %%
padding_size
# Out:
# 1

# %%
# sample 
a1 =[
    [1,2,3,4,5,6,7],
    [4,5,6,1,2,3,4],
    [4,5,6,1,2,3,4]
]

# param 
window_size = 4

def add_padding(img , window_size):
    
    a1 = img
    # row add 
    row_padding_size = window_size - len(a1[0]) % window_size

    for col in range(len(a1)):
        col_arrays = a1[col]
        
        for _ in range(row_padding_size):
            col_arrays.append(0)

    # col add 
    row_padding_size = window_size - len(a1) % window_size

    if row_padding_size == window_size:
        pass
    else:
        print(row_padding_size)
        for _ in range(row_padding_size):
            a1.append([0 for i in range(len(a1[0]))])
    
    return a1

# %%
np_img =  np.array(img_)

# %%
list_img = np_img.tolist()

# %%
rr = add_padding(list_img, 100)
# Out:
# 80

# %%
len(rr), len(rr[0])
# Out:
# (7300, 7500)

# %%
rr_array = np.array(rr)
# Out:
# /tmp/ipykernel_4005352/4018142943.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   rr_array = np.array(rr)

# %%
plt.imshow(rr_array)

# %%
# 아 이거,, rgb point style 

# sample 
a1 =[
    [1,2,3,4,5,6,7],
    [4,5,6,1,2,3,4],
    [4,5,6,1,2,3,4]
]

# param 
window_size = 4

def add_padding(img , window_size):
    
    a1 = img
    # row add 
    row_padding_size = window_size - len(a1[0]) % window_size

    for col in range(len(a1)):
        col_arrays = a1[col]
        
        for _ in range(row_padding_size):
            col_arrays.append(0)

    # col add 
    row_padding_size = window_size - len(a1) % window_size

    if row_padding_size == window_size:
        pass
    else:
        print(row_padding_size)
        for _ in range(row_padding_size):
            a1.append([0 for i in range(len(a1[0]))])
    
    return a1

# %%
row_padding_size = window_size - len(a1) % window_size

# %%
row_padding_size
# Out:
# 1

# %%
row_padding_size = window_size - len(a1) % window_size

if row_padding_size == window_size:
    pass
else:
    print(row_padding_size)
    for _ in range(row_padding_size):
        a1.append([0 for i in range(len(a1[0]))])

a1
# Out:
# 1
# [[1, 2, 3, 4, 5, 6, 7, 0],
#  [4, 5, 6, 1, 2, 3, 4, 0],
#  [4, 5, 6, 1, 2, 3, 4, 0],
#  [0, 0, 0, 0, 0, 0, 0, 0]]

# %%
3 % 3
# Out:
# 0

# %%
3 % 3
# Out:
# 0

# %%
np_img = np.array(img_)

# %%
padding_size = 100
for row in range(len(np_img)):
    row_arrays = np_img[row]

    for _ in range(padding_size):
        row_arrays.append([0,0,0,255])

# %%
np_img[7219][0]
# Out:
# array([  0,   0,   0, 255], dtype=uint8)

# %%
rows, cols = img_.size[0], img_.size[1]
for row in range(rows):
    for col in range(cols):
# Out:
#   Cell In[12], line 4
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
img_.size[0], img_.size[0]//100
# Out:
# (7410, 74)

# %%
rows, cols = img_.size[0], img_.size[1]
for row in range(rows):
    for col in range(cols):
        window_size = 100 
        np_img[row+]
