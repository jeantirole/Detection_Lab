# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
log_ = sorted(os.listdir("./01.log"))[-1]
f = open(os.path.join("./01.log", log_))
lines = f.readlines()

# %%
print(log_)
# Out:
# ver_23_2024-04-02_14-55-46.log

# %%
for line in lines:
    print(line.split())
# Out:
# ['epoch', ':', '0', 'iter', ':', '0', 'loss:', '2.15599', 'dice:', '0.09115']
# ['epoch', ':', '0', 'iter', ':', '0', 'loss:', '2.19148', 'dice:', '0.05779']
# ['epoch', ':', '0', 'iter', ':', '0', 'loss:', '2.18593', 'dice:', '0.06813']
# ['epoch', ':', '0', 'iter', ':', '0', 'loss:', '2.16110', 'dice:', '0.08518']
# ['epoch', ':', '0', 'iter', ':', '1', 'loss:', '2.16595', 'dice:', '0.07194']
# ['epoch', ':', '0', 'iter', ':', '1', 'loss:', '2.19597', 'dice:', '0.04828']
# ['epoch', ':', '0', 'iter', ':', '1', 'loss:', '2.19495', 'dice:', '0.04827']
# ['epoch', ':', '0', 'iter', ':', '1', 'loss:', '2.15536', 'dice:', '0.08725']
# ['epoch', ':', '0', 'iter', ':', '2', 'loss:', '2.13847', 'dice:', '0.09073']
# ['epoch', ':', '0', 'iter', ':', '2', 'loss:', '2.18354', 'dice:', '0.06646']
# ['epoch', ':', '0', 'iter', ':', '2', 'loss:', '2.13801', 'dice:', '0.08622']
# ['epoch', ':', '0', 'iter', ':', '2', 'loss:', '2.13369', 'dice:', '0.07902']
# ['epoch', ':', '0', 'iter', ':', '3', 'loss:', '2.11733', 'dice:', '0.10349']
# ['epoch', ':', '0', 'iter', ':', '3', 'loss:', '2.14362', 'dice:', '0.07815']
# ['epoch', ':', '0', 'iter', ':', '3', 'loss:', '2.13500', 'dice:', '0.08235']
# ['epoch', ':', '0', 'iter', ':', '3', 'loss:', '2.15604', 'dice:', '0.06683']
# ['epoch', ':', '0', 'iter', ':', '4', 'loss:', '2.14294', 'dice:', '0.07214']
# ['epoch', ':', '0', 'iter', ':', '4', 'loss:', '2.11945', 'dice:', '0.07907']
# ['epoch', ':', '0', 'iter', ':', '4', 'loss:', '2.12883', 'dice:', '0.08476']
# ['epoch', ':', '0', 'iter', ':', '4', 'loss:', '2.05512', 'dice:', '0.13265']
# ['epoch', ':', '0', 'iter', ':', '5', 'loss:', '2.09323', 'dice:', '0.09248']
# ['epoch', ':', '0', 'iter', ':', '5', 'loss:', '2.14140', 'dice:', '0.07622']
# ['epoch', ':', '0', 'iter', ':', '5', 'loss:', '2.11912', 'dice:', '0.08343']
# ['epoch', ':', '0', 'iter', ':', '5', 'loss:', '2.12588', 'dice:', '0.08224']
# ['epoch', ':', '0', 'iter', ':', '6', 'loss:', '2.11304', 'dice:', '0.08674']
# ['epoch', ':', '0', 'iter', ':', '6', 'loss:', '2.11774', 'dice:', '0.08222']
# ['epoch', ':', '0', 'iter', ':', '6', 'loss:', '2.07172', 'dice:', '0.10645']
# ['epoch', ':', '0', 'iter', ':', '6', 'loss:', '2.05543', 'dice:', '0.11312']
# ['epoch', ':', '0', 'iter', ':', '7', 'loss:', '2.06097', 'dice:', '0.10669']
# ['epoch', ':', '0', 'iter', ':', '7', 'loss:', '2.07034', 'dice:', '0.09603']
# ['epoch', ':', '0', 'iter', ':', '7', 'loss:', '2.10703', 'dice:', '0.08678']
# ['epoch', ':', '0', 'iter', ':', '7', 'loss:', '2.07988', 'dice:', '0.10380']
# ['epoch', ':', '0', 'iter', ':', '8', 'loss:', '2.12215', 'dice:', '0.06734']
# ['epoch', ':', '0', 'iter', ':', '8', 'loss:', '2.06004', 'dice:', '0.10410']
# ['epoch', ':', '0', 'iter', ':', '8', 'loss:', '2.09762', 'dice:', '0.08114']
# ['epoch', ':', '0', 'iter', ':', '8', 'loss:', '2.00409', 'dice:', '0.12697']
# ['epoch', ':', '0', 'iter', ':', '9', 'loss:', '2.01734', 'dice:', '0.13373']
# ['epoch', ':', '0', 'iter', ':', '9', 'loss:', '2.08644', 'dice:', '0.09470']
# ['epoch', ':', '0', 'iter', ':', '9', 'loss:', '2.02534', 'dice:', '0.11804']
# ['epoch', ':', '0', 'iter', ':', '9', 'loss:', '2.01145', 'dice:', '0.11985']
# ['epoch', ':', '0', 'iter', ':', '10', 'loss:', '2.08609', 'dice:', '0.08783']
# ['epoch', ':', '0', 'iter', ':', '10', 'loss:', '2.03011', 'dice:', '0.11594']
# ['epoch', ':', '0', 'iter', ':', '10', 'loss:', '2.03162', 'dice:', '0.12130']
# ['epoch', ':', '0', 'iter', ':', '10', 'loss:', '2.04650', 'dice:', '0.10268']
# ['epoch', ':', '0', 'iter', ':', '11', 'loss:', '2.00671', 'dice:', '0.12688']
# ['epoch', ':', '0', 'iter', ':', '11', 'loss:', '1.97037', 'dice:', '0.13368']
# ['epoch', ':', '0', 'iter', ':', '11', 'loss:', '2.02403', 'dice:', '0.12069']
# ['epoch', ':', '0', 'iter', ':', '11', 'loss:', '2.06211', 'dice:', '0.08928']
# ['epoch', ':', '0', 'iter', ':', '12', 'loss:', '2.05418', 'dice:', '0.08123']
# ['epoch', ':', '0', 'iter', ':', '12', 'loss:', '2.06548', 'dice:', '0.09673']
# ['epoch', ':', '0', 'iter', ':', '12', 'loss:', '1.80123', 'dice:', '0.26535']
# ['epoch', ':', '0', 'iter', ':', '12', 'loss:', '1.76876', 'dice:', '0.29331']
# ['epoch', ':', '1', 'iter', ':', '0', 'loss:', '1.98584', 'dice:', '0.13106']
# ['epoch', ':', '1', 'iter', ':', '0', 'loss:', '1.92923', 'dice:', '0.15459']
# ['epoch', ':', '1', 'iter', ':', '0', 'loss:', '1.97971', 'dice:', '0.12776']
# ['epoch', ':', '1', 'iter', ':', '0', 'loss:', '1.99932', 'dice:', '0.11360']
# ['epoch', ':', '1', 'iter', ':', '1', 'loss:', '2.03419', 'dice:', '0.09286']
# ['epoch', ':', '1', 'iter', ':', '1', 'loss:', '1.99724', 'dice:', '0.12691']
# ['epoch', ':', '1', 'iter', ':', '1', 'loss:', '2.02312', 'dice:', '0.09937']
# ['epoch', ':', '1', 'iter', ':', '1', 'loss:', '1.99441', 'dice:', '0.10624']
# ['epoch', ':', '1', 'iter', ':', '2', 'loss:', '1.93292', 'dice:', '0.14663']
# ['epoch', ':', '1', 'iter', ':', '2', 'loss:', '1.95659', 'dice:', '0.14158']
# ['epoch', ':', '1', 'iter', ':', '2', 'loss:', '1.91810', 'dice:', '0.14447']
# ['epoch', ':', '1', 'iter', ':', '2', 'loss:', '2.01530', 'dice:', '0.10233']
# ['epoch', ':', '1', 'iter', ':', '3', 'loss:', '2.06671', 'dice:', '0.06814']
# ['epoch', ':', '1', 'iter', ':', '3', 'loss:', '1.97919', 'dice:', '0.12939']
# ['epoch', ':', '1', 'iter', ':', '3', 'loss:', '1.92518', 'dice:', '0.15240']
# ['epoch', ':', '1', 'iter', ':', '3', 'loss:', '1.98981', 'dice:', '0.11288']
# ['epoch', ':', '1', 'iter', ':', '4', 'loss:', '1.97004', 'dice:', '0.11415']
# ['epoch', ':', '1', 'iter', ':', '4', 'loss:', '1.98334', 'dice:', '0.11146']
# ['epoch', ':', '1', 'iter', ':', '4', 'loss:', '1.87916', 'dice:', '0.15272']
# ['epoch', ':', '1', 'iter', ':', '4', 'loss:', '1.88209', 'dice:', '0.17106']
# ['epoch', ':', '1', 'iter', ':', '5', 'loss:', '2.00870', 'dice:', '0.10046']
# ['epoch', ':', '1', 'iter', ':', '5', 'loss:', '1.87051', 'dice:', '0.17928']
# ['epoch', ':', '1', 'iter', ':', '5', 'loss:', '1.96793', 'dice:', '0.13098']
# ['epoch', ':', '1', 'iter', ':', '5', 'loss:', '1.91277', 'dice:', '0.14727']
# ['epoch', ':', '1', 'iter', ':', '6', 'loss:', '1.84816', 'dice:', '0.18037']
# ['epoch', ':', '1', 'iter', ':', '6', 'loss:', '1.99609', 'dice:', '0.10904']
# ['epoch', ':', '1', 'iter', ':', '6', 'loss:', '1.91843', 'dice:', '0.14288']
# ['epoch', ':', '1', 'iter', ':', '6', 'loss:', '1.89624', 'dice:', '0.15325']
# ['epoch', ':', '1', 'iter', ':', '7', 'loss:', '1.82821', 'dice:', '0.17438']
# ['epoch', ':', '1', 'iter', ':', '7', 'loss:', '1.86476', 'dice:', '0.15379']
# ['epoch', ':', '1', 'iter', ':', '7', 'loss:', '1.98955', 'dice:', '0.10135']
# ['epoch', ':', '1', 'iter', ':', '7', 'loss:', '1.88450', 'dice:', '0.15438']
# ['epoch', ':', '1', 'iter', ':', '8', 'loss:', '1.91413', 'dice:', '0.12454']
# ['epoch', ':', '1', 'iter', ':', '8', 'loss:', '1.86100', 'dice:', '0.17282']
# ['epoch', ':', '1', 'iter', ':', '8', 'loss:', '1.95830', 'dice:', '0.11213']
# ['epoch', ':', '1', 'iter', ':', '8', 'loss:', '1.89232', 'dice:', '0.14848']
# ['epoch', ':', '1', 'iter', ':', '9', 'loss:', '1.86607', 'dice:', '0.15514']
# ['epoch', ':', '1', 'iter', ':', '9', 'loss:', '1.93609', 'dice:', '0.14035']
# ['epoch', ':', '1', 'iter', ':', '9', 'loss:', '1.87337', 'dice:', '0.14569']
# ['epoch', ':', '1', 'iter', ':', '9', 'loss:', '1.86992', 'dice:', '0.16100']
# ['epoch', ':', '1', 'iter', ':', '10', 'loss:', '1.91498', 'dice:', '0.12989']
# ['epoch', ':', '1', 'iter', ':', '10', 'loss:', '1.87480', 'dice:', '0.15323']
# ['epoch', ':', '1', 'iter', ':', '10', 'loss:', '1.91290', 'dice:', '0.15012']
# ['epoch', ':', '1', 'iter', ':', '10', 'loss:', '1.88705', 'dice:', '0.15646']
# ['epoch', ':', '1', 'iter', ':', '11', 'loss:', '1.84664', 'dice:', '0.15516']
# ['epoch', ':', '1', 'iter', ':', '11', 'loss:', '1.83049', 'dice:', '0.17529']
# ['epoch', ':', '1', 'iter', ':', '11', 'loss:', '1.87028', 'dice:', '0.16355']
# ['epoch', ':', '1', 'iter', ':', '11', 'loss:', '1.85705', 'dice:', '0.16300']
# ['epoch', ':', '1', 'iter', ':', '12', 'loss:', '1.87738', 'dice:', '0.16902']
# ['epoch', ':', '1', 'iter', ':', '12', 'loss:', '1.68602', 'dice:', '0.26709']
# ['epoch', ':', '1', 'iter', ':', '12', 'loss:', '2.03891', 'dice:', '0.08561']
# ['epoch', ':', '1', 'iter', ':', '12', 'loss:', '1.82793', 'dice:', '0.20251']
# ['epoch', ':', '2', 'iter', ':', '0', 'loss:', '1.85549', 'dice:', '0.16093']
# ['epoch', ':', '2', 'iter', ':', '0', 'loss:', '1.89531', 'dice:', '0.13520']
# ['epoch', ':', '2', 'iter', ':', '0', 'loss:', '1.80329', 'dice:', '0.19247']
# ['epoch', ':', '2', 'iter', ':', '0', 'loss:', '1.85160', 'dice:', '0.14841']
# ['epoch', ':', '2', 'iter', ':', '1', 'loss:', '1.74860', 'dice:', '0.22771']
# ['epoch', ':', '2', 'iter', ':', '1', 'loss:', '1.84632', 'dice:', '0.14974']
# ['epoch', ':', '2', 'iter', ':', '1', 'loss:', '1.86232', 'dice:', '0.14727']
# ['epoch', ':', '2', 'iter', ':', '1', 'loss:', '1.88159', 'dice:', '0.13646']
# ['epoch', ':', '2', 'iter', ':', '2', 'loss:', '1.80418', 'dice:', '0.18986']
# ['epoch', ':', '2', 'iter', ':', '2', 'loss:', '1.84340', 'dice:', '0.16054']
# ['epoch', ':', '2', 'iter', ':', '2', 'loss:', '1.75491', 'dice:', '0.20723']
# ['epoch', ':', '2', 'iter', ':', '2', 'loss:', '1.68955', 'dice:', '0.25883']
# ['epoch', ':', '2', 'iter', ':', '3', 'loss:', '1.83967', 'dice:', '0.17039']
# ['epoch', ':', '2', 'iter', ':', '3', 'loss:', '1.80486', 'dice:', '0.17694']
# ['epoch', ':', '2', 'iter', ':', '3', 'loss:', '1.90009', 'dice:', '0.14367']
# ['epoch', ':', '2', 'iter', ':', '3', 'loss:', '1.89136', 'dice:', '0.13828']
# ['epoch', ':', '2', 'iter', ':', '4', 'loss:', '1.87070', 'dice:', '0.15989']
# ['epoch', ':', '2', 'iter', ':', '4', 'loss:', '1.77848', 'dice:', '0.20188']
# ['epoch', ':', '2', 'iter', ':', '4', 'loss:', '1.83408', 'dice:', '0.14883']
# ['epoch', ':', '2', 'iter', ':', '4', 'loss:', '1.78378', 'dice:', '0.19336']
# ['epoch', ':', '2', 'iter', ':', '5', 'loss:', '1.80938', 'dice:', '0.16326']
# ['epoch', ':', '2', 'iter', ':', '5', 'loss:', '1.78372', 'dice:', '0.18764']
# ['epoch', ':', '2', 'iter', ':', '5', 'loss:', '1.74122', 'dice:', '0.21252']
# ['epoch', ':', '2', 'iter', ':', '5', 'loss:', '1.83106', 'dice:', '0.16730']
# ['epoch', ':', '2', 'iter', ':', '6', 'loss:', '1.83976', 'dice:', '0.15990']
# ['epoch', ':', '2', 'iter', ':', '6', 'loss:', '1.80789', 'dice:', '0.18409']
# ['epoch', ':', '2', 'iter', ':', '6', 'loss:', '1.85995', 'dice:', '0.13597']
# ['epoch', ':', '2', 'iter', ':', '6', 'loss:', '1.76910', 'dice:', '0.18774']
# ['epoch', ':', '2', 'iter', ':', '7', 'loss:', '1.79652', 'dice:', '0.17148']
# ['epoch', ':', '2', 'iter', ':', '7', 'loss:', '1.70694', 'dice:', '0.23276']
# ['epoch', ':', '2', 'iter', ':', '7', 'loss:', '1.70656', 'dice:', '0.23117']
# ['epoch', ':', '2', 'iter', ':', '7', 'loss:', '1.82685', 'dice:', '0.15171']
# ['epoch', ':', '2', 'iter', ':', '8', 'loss:', '1.66988', 'dice:', '0.24783']
# ['epoch', ':', '2', 'iter', ':', '8', 'loss:', '1.81807', 'dice:', '0.16545']
# ['epoch', ':', '2', 'iter', ':', '8', 'loss:', '1.86528', 'dice:', '0.13286']
# ['epoch', ':', '2', 'iter', ':', '8', 'loss:', '1.74198', 'dice:', '0.19359']
# ['epoch', ':', '2', 'iter', ':', '9', 'loss:', '1.81083', 'dice:', '0.17651']
# ['epoch', ':', '2', 'iter', ':', '9', 'loss:', '1.78544', 'dice:', '0.17730']
# ['epoch', ':', '2', 'iter', ':', '9', 'loss:', '1.76452', 'dice:', '0.19146']
# ['epoch', ':', '2', 'iter', ':', '9', 'loss:', '1.67999', 'dice:', '0.24032']
# ['epoch', ':', '2', 'iter', ':', '10', 'loss:', '1.81555', 'dice:', '0.16236']
# ['epoch', ':', '2', 'iter', ':', '10', 'loss:', '1.89042', 'dice:', '0.11982']
# ['epoch', ':', '2', 'iter', ':', '10', 'loss:', '1.76530', 'dice:', '0.18140']
# ['epoch', ':', '2', 'iter', ':', '10', 'loss:', '1.77907', 'dice:', '0.17451']
# ['epoch', ':', '2', 'iter', ':', '11', 'loss:', '1.79559', 'dice:', '0.17931']
# ['epoch', ':', '2', 'iter', ':', '11', 'loss:', '1.79733', 'dice:', '0.16455']
# ['epoch', ':', '2', 'iter', ':', '11', 'loss:', '1.79124', 'dice:', '0.16178']
# ['epoch', ':', '2', 'iter', ':', '11', 'loss:', '1.74068', 'dice:', '0.19037']
# ['epoch', ':', '2', 'iter', ':', '12', 'loss:', '1.92091', 'dice:', '0.12023']
# ['epoch', ':', '2', 'iter', ':', '12', 'loss:', '2.01914', 'dice:', '0.07774']
# ['epoch', ':', '2', 'iter', ':', '12', 'loss:', '2.00863', 'dice:', '0.09934']
# ['epoch', ':', '2', 'iter', ':', '12', 'loss:', '1.97805', 'dice:', '0.09221']
# ['epoch', ':', '3', 'iter', ':', '0', 'loss:', '1.75819', 'dice:', '0.18662']
# ['epoch', ':', '3', 'iter', ':', '0', 'loss:', '1.73360', 'dice:', '0.21454']
# ['epoch', ':', '3', 'iter', ':', '0', 'loss:', '1.77939', 'dice:', '0.16952']
# ['epoch', ':', '3', 'iter', ':', '0', 'loss:', '1.70404', 'dice:', '0.22298']
# ['epoch', ':', '3', 'iter', ':', '1', 'loss:', '1.81958', 'dice:', '0.15321']
# ['epoch', ':', '3', 'iter', ':', '1', 'loss:', '1.79822', 'dice:', '0.16686']
# ['epoch', ':', '3', 'iter', ':', '1', 'loss:', '1.66230', 'dice:', '0.24528']
# ['epoch', ':', '3', 'iter', ':', '1', 'loss:', '1.75871', 'dice:', '0.18058']
# ['epoch', ':', '3', 'iter', ':', '2', 'loss:', '1.63050', 'dice:', '0.26459']
# ['epoch', ':', '3', 'iter', ':', '2', 'loss:', '1.77998', 'dice:', '0.17069']
# ['epoch', ':', '3', 'iter', ':', '2', 'loss:', '1.62708', 'dice:', '0.28122']
# ['epoch', ':', '3', 'iter', ':', '2', 'loss:', '1.76756', 'dice:', '0.18669']
# ['epoch', ':', '3', 'iter', ':', '3', 'loss:', '1.65994', 'dice:', '0.26253']
# ['epoch', ':', '3', 'iter', ':', '3', 'loss:', '1.72352', 'dice:', '0.20419']
# ['epoch', ':', '3', 'iter', ':', '3', 'loss:', '1.75784', 'dice:', '0.18668']
# ['epoch', ':', '3', 'iter', ':', '3', 'loss:', '1.76345', 'dice:', '0.18097']
# ['epoch', ':', '3', 'iter', ':', '4', 'loss:', '1.69308', 'dice:', '0.21443']
# ['epoch', ':', '3', 'iter', ':', '4', 'loss:', '1.77224', 'dice:', '0.17408']
# ['epoch', ':', '3', 'iter', ':', '4', 'loss:', '1.71456', 'dice:', '0.21163']
# ['epoch', ':', '3', 'iter', ':', '4', 'loss:', '1.71129', 'dice:', '0.22733']
# ['epoch', ':', '3', 'iter', ':', '5', 'loss:', '1.65751', 'dice:', '0.22858']
# ['epoch', ':', '3', 'iter', ':', '5', 'loss:', '1.69586', 'dice:', '0.21023']
# ['epoch', ':', '3', 'iter', ':', '5', 'loss:', '1.69895', 'dice:', '0.21910']
# ['epoch', ':', '3', 'iter', ':', '5', 'loss:', '1.76598', 'dice:', '0.17266']
# ['epoch', ':', '3', 'iter', ':', '6', 'loss:', '1.75520', 'dice:', '0.17119']
# ['epoch', ':', '3', 'iter', ':', '6', 'loss:', '1.77616', 'dice:', '0.15847']
# ['epoch', ':', '3', 'iter', ':', '6', 'loss:', '1.66029', 'dice:', '0.23392']
# ['epoch', ':', '3', 'iter', ':', '6', 'loss:', '1.66726', 'dice:', '0.22892']
# ['epoch', ':', '3', 'iter', ':', '7', 'loss:', '1.70910', 'dice:', '0.20294']
# ['epoch', ':', '3', 'iter', ':', '7', 'loss:', '1.66888', 'dice:', '0.22654']
# ['epoch', ':', '3', 'iter', ':', '7', 'loss:', '1.77714', 'dice:', '0.17003']
# ['epoch', ':', '3', 'iter', ':', '7', 'loss:', '1.69746', 'dice:', '0.21514']
# ['epoch', ':', '3', 'iter', ':', '8', 'loss:', '1.67456', 'dice:', '0.23833']
# ['epoch', ':', '3', 'iter', ':', '8', 'loss:', '1.77435', 'dice:', '0.15946']
# ['epoch', ':', '3', 'iter', ':', '8', 'loss:', '1.68185', 'dice:', '0.19433']
# ['epoch', ':', '3', 'iter', ':', '8', 'loss:', '1.68185', 'dice:', '0.21417']
# ['epoch', ':', '3', 'iter', ':', '9', 'loss:', '1.70330', 'dice:', '0.20871']
# ['epoch', ':', '3', 'iter', ':', '9', 'loss:', '1.77967', 'dice:', '0.16155']
# ['epoch', ':', '3', 'iter', ':', '9', 'loss:', '1.69151', 'dice:', '0.21052']
# ['epoch', ':', '3', 'iter', ':', '9', 'loss:', '1.63661', 'dice:', '0.23439']
# ['epoch', ':', '3', 'iter', ':', '10', 'loss:', '1.63270', 'dice:', '0.22631']
# ['epoch', ':', '3', 'iter', ':', '10', 'loss:', '1.56984', 'dice:', '0.29311']
# ['epoch', ':', '3', 'iter', ':', '10', 'loss:', '1.65119', 'dice:', '0.24408']
# ['epoch', ':', '3', 'iter', ':', '10', 'loss:', '1.67300', 'dice:', '0.21429']
# ['epoch', ':', '3', 'iter', ':', '11', 'loss:', '1.71965', 'dice:', '0.18661']
# ['epoch', ':', '3', 'iter', ':', '11', 'loss:', '1.69035', 'dice:', '0.20556']
# ['epoch', ':', '3', 'iter', ':', '11', 'loss:', '1.62477', 'dice:', '0.25980']
# ['epoch', ':', '3', 'iter', ':', '11', 'loss:', '1.69827', 'dice:', '0.18596']
# ['epoch', ':', '3', 'iter', ':', '12', 'loss:', '1.71903', 'dice:', '0.21333']
# ['epoch', ':', '3', 'iter', ':', '12', 'loss:', '1.61997', 'dice:', '0.25618']
# ['epoch', ':', '3', 'iter', ':', '12', 'loss:', '1.62379', 'dice:', '0.29373']
# ['epoch', ':', '3', 'iter', ':', '12', 'loss:', '1.55153', 'dice:', '0.29473']
# ['epoch', ':', '4', 'iter', ':', '0', 'loss:', '1.63174', 'dice:', '0.23713']
# ['epoch', ':', '4', 'iter', ':', '0', 'loss:', '1.59697', 'dice:', '0.27102']
# ['epoch', ':', '4', 'iter', ':', '0', 'loss:', '1.58967', 'dice:', '0.27057']
# ['epoch', ':', '4', 'iter', ':', '0', 'loss:', '1.62436', 'dice:', '0.22793']
# ['epoch', ':', '4', 'iter', ':', '1', 'loss:', '1.70978', 'dice:', '0.19163']
# ['epoch', ':', '4', 'iter', ':', '1', 'loss:', '1.59782', 'dice:', '0.25640']
# ['epoch', ':', '4', 'iter', ':', '1', 'loss:', '1.73093', 'dice:', '0.17307']
# ['epoch', ':', '4', 'iter', ':', '1', 'loss:', '1.56649', 'dice:', '0.28394']
# ['epoch', ':', '4', 'iter', ':', '2', 'loss:', '1.62676', 'dice:', '0.23878']
# ['epoch', ':', '4', 'iter', ':', '2', 'loss:', '1.57735', 'dice:', '0.26903']
# ['epoch', ':', '4', 'iter', ':', '2', 'loss:', '1.69419', 'dice:', '0.18858']
# ['epoch', ':', '4', 'iter', ':', '2', 'loss:', '1.76276', 'dice:', '0.16873']
# ['epoch', ':', '4', 'iter', ':', '3', 'loss:', '1.70496', 'dice:', '0.20951']
# ['epoch', ':', '4', 'iter', ':', '3', 'loss:', '1.60894', 'dice:', '0.26319']
# ['epoch', ':', '4', 'iter', ':', '3', 'loss:', '1.63883', 'dice:', '0.21810']
# ['epoch', ':', '4', 'iter', ':', '3', 'loss:', '1.68950', 'dice:', '0.20933']
# ['epoch', ':', '4', 'iter', ':', '4', 'loss:', '1.62678', 'dice:', '0.24791']
# ['epoch', ':', '4', 'iter', ':', '4', 'loss:', '1.58827', 'dice:', '0.25241']
# ['epoch', ':', '4', 'iter', ':', '4', 'loss:', '1.62129', 'dice:', '0.23745']
# ['epoch', ':', '4', 'iter', ':', '4', 'loss:', '1.75582', 'dice:', '0.14853']
# ['epoch', ':', '4', 'iter', ':', '5', 'loss:', '1.60341', 'dice:', '0.24829']
# ['epoch', ':', '4', 'iter', ':', '5', 'loss:', '1.65807', 'dice:', '0.22817']
# ['epoch', ':', '4', 'iter', ':', '5', 'loss:', '1.73196', 'dice:', '0.16688']
# ['epoch', ':', '4', 'iter', ':', '5', 'loss:', '1.66323', 'dice:', '0.20697']
# ['epoch', ':', '4', 'iter', ':', '6', 'loss:', '1.61340', 'dice:', '0.24283']
# ['epoch', ':', '4', 'iter', ':', '6', 'loss:', '1.64318', 'dice:', '0.22785']
# ['epoch', ':', '4', 'iter', ':', '6', 'loss:', '1.70851', 'dice:', '0.18375']
# ['epoch', ':', '4', 'iter', ':', '6', 'loss:', '1.68276', 'dice:', '0.20683']
# ['epoch', ':', '4', 'iter', ':', '7', 'loss:', '1.65446', 'dice:', '0.22570']
# ['epoch', ':', '4', 'iter', ':', '7', 'loss:', '1.70263', 'dice:', '0.19378']
# ['epoch', ':', '4', 'iter', ':', '7', 'loss:', '1.56988', 'dice:', '0.26713']
# ['epoch', ':', '4', 'iter', ':', '7', 'loss:', '1.67097', 'dice:', '0.21760']
# ['epoch', ':', '4', 'iter', ':', '8', 'loss:', '1.55069', 'dice:', '0.28017']
# ['epoch', ':', '4', 'iter', ':', '8', 'loss:', '1.62785', 'dice:', '0.24108']
# ['epoch', ':', '4', 'iter', ':', '8', 'loss:', '1.68392', 'dice:', '0.20853']
# ['epoch', ':', '4', 'iter', ':', '8', 'loss:', '1.63177', 'dice:', '0.22558']
# ['epoch', ':', '4', 'iter', ':', '9', 'loss:', '1.78324', 'dice:', '0.15262']
# ['epoch', ':', '4', 'iter', ':', '9', 'loss:', '1.55898', 'dice:', '0.28372']
# ['epoch', ':', '4', 'iter', ':', '9', 'loss:', '1.54729', 'dice:', '0.28587']
# ['epoch', ':', '4', 'iter', ':', '9', 'loss:', '1.63308', 'dice:', '0.23609']
# ['epoch', ':', '4', 'iter', ':', '10', 'loss:', '1.63911', 'dice:', '0.22272']
# ['epoch', ':', '4', 'iter', ':', '10', 'loss:', '1.61440', 'dice:', '0.24306']
# ['epoch', ':', '4', 'iter', ':', '10', 'loss:', '1.68904', 'dice:', '0.18194']
# ['epoch', ':', '4', 'iter', ':', '10', 'loss:', '1.65543', 'dice:', '0.21116']
# ['epoch', ':', '4', 'iter', ':', '11', 'loss:', '1.57392', 'dice:', '0.27144']
# ['epoch', ':', '4', 'iter', ':', '11', 'loss:', '1.57957', 'dice:', '0.26744']
# ['epoch', ':', '4', 'iter', ':', '11', 'loss:', '1.63329', 'dice:', '0.23247']
# ['epoch', ':', '4', 'iter', ':', '11', 'loss:', '1.66401', 'dice:', '0.20858']
# ['epoch', ':', '4', 'iter', ':', '12', 'loss:', '1.43034', 'dice:', '0.39945']
# ['epoch', ':', '4', 'iter', ':', '12', 'loss:', '1.60279', 'dice:', '0.25811']
# ['epoch', ':', '4', 'iter', ':', '12', 'loss:', '1.94821', 'dice:', '0.10423']
# ['epoch', ':', '4', 'iter', ':', '12', 'loss:', '1.74468', 'dice:', '0.17659']
# ['epoch', ':', '5', 'iter', ':', '0', 'loss:', '1.59988', 'dice:', '0.23221']
# ['epoch', ':', '5', 'iter', ':', '0', 'loss:', '1.66246', 'dice:', '0.20701']
# ['epoch', ':', '5', 'iter', ':', '0', 'loss:', '1.63770', 'dice:', '0.20554']
# ['epoch', ':', '5', 'iter', ':', '0', 'loss:', '1.67026', 'dice:', '0.19255']
# ['epoch', ':', '5', 'iter', ':', '1', 'loss:', '1.53076', 'dice:', '0.29902']
# ['epoch', ':', '5', 'iter', ':', '1', 'loss:', '1.52219', 'dice:', '0.29819']
# ['epoch', ':', '5', 'iter', ':', '1', 'loss:', '1.57947', 'dice:', '0.27569']
# ['epoch', ':', '5', 'iter', ':', '1', 'loss:', '1.60040', 'dice:', '0.25255']
# ['epoch', ':', '5', 'iter', ':', '2', 'loss:', '1.64074', 'dice:', '0.21196']
# ['epoch', ':', '5', 'iter', ':', '2', 'loss:', '1.54485', 'dice:', '0.28218']
# ['epoch', ':', '5', 'iter', ':', '2', 'loss:', '1.68456', 'dice:', '0.19363']
# ['epoch', ':', '5', 'iter', ':', '2', 'loss:', '1.61526', 'dice:', '0.24592']
# ['epoch', ':', '5', 'iter', ':', '3', 'loss:', '1.60280', 'dice:', '0.23497']
# ['epoch', ':', '5', 'iter', ':', '3', 'loss:', '1.58649', 'dice:', '0.23915']
# ['epoch', ':', '5', 'iter', ':', '3', 'loss:', '1.59966', 'dice:', '0.23927']
# ['epoch', ':', '5', 'iter', ':', '3', 'loss:', '1.56075', 'dice:', '0.26793']
# ['epoch', ':', '5', 'iter', ':', '4', 'loss:', '1.62565', 'dice:', '0.22472']
# ['epoch', ':', '5', 'iter', ':', '4', 'loss:', '1.58124', 'dice:', '0.24557']
# ['epoch', ':', '5', 'iter', ':', '4', 'loss:', '1.75807', 'dice:', '0.15094']
# ['epoch', ':', '5', 'iter', ':', '4', 'loss:', '1.72418', 'dice:', '0.16223']
# ['epoch', ':', '5', 'iter', ':', '5', 'loss:', '1.60727', 'dice:', '0.21658']
# ['epoch', ':', '5', 'iter', ':', '5', 'loss:', '1.49947', 'dice:', '0.29515']
# ['epoch', ':', '5', 'iter', ':', '5', 'loss:', '1.55882', 'dice:', '0.26111']
# ['epoch', ':', '5', 'iter', ':', '5', 'loss:', '1.61447', 'dice:', '0.21723']
# ['epoch', ':', '5', 'iter', ':', '6', 'loss:', '1.58211', 'dice:', '0.23745']
# ['epoch', ':', '5', 'iter', ':', '6', 'loss:', '1.57071', 'dice:', '0.25111']
# ['epoch', ':', '5', 'iter', ':', '6', 'loss:', '1.54668', 'dice:', '0.26867']
# ['epoch', ':', '5', 'iter', ':', '6', 'loss:', '1.54699', 'dice:', '0.25713']
# ['epoch', ':', '5', 'iter', ':', '7', 'loss:', '1.41608', 'dice:', '0.37151']
# ['epoch', ':', '5', 'iter', ':', '7', 'loss:', '1.62191', 'dice:', '0.21645']
# ['epoch', ':', '5', 'iter', ':', '7', 'loss:', '1.58785', 'dice:', '0.22704']
# ['epoch', ':', '5', 'iter', ':', '7', 'loss:', '1.59165', 'dice:', '0.22744']
# ['epoch', ':', '5', 'iter', ':', '8', 'loss:', '1.59425', 'dice:', '0.23925']
# ['epoch', ':', '5', 'iter', ':', '8', 'loss:', '1.67359', 'dice:', '0.19955']
# ['epoch', ':', '5', 'iter', ':', '8', 'loss:', '1.51737', 'dice:', '0.30646']
# ['epoch', ':', '5', 'iter', ':', '8', 'loss:', '1.51646', 'dice:', '0.29590']
# ['epoch', ':', '5', 'iter', ':', '9', 'loss:', '1.52988', 'dice:', '0.28632']
# ['epoch', ':', '5', 'iter', ':', '9', 'loss:', '1.58902', 'dice:', '0.24361']
# ['epoch', ':', '5', 'iter', ':', '9', 'loss:', '1.52384', 'dice:', '0.31037']
# ['epoch', ':', '5', 'iter', ':', '9', 'loss:', '1.66069', 'dice:', '0.18719']
# ['epoch', ':', '5', 'iter', ':', '10', 'loss:', '1.68431', 'dice:', '0.18654']
# ['epoch', ':', '5', 'iter', ':', '10', 'loss:', '1.64209', 'dice:', '0.19805']
# ['epoch', ':', '5', 'iter', ':', '10', 'loss:', '1.57736', 'dice:', '0.23788']
# ['epoch', ':', '5', 'iter', ':', '10', 'loss:', '1.53958', 'dice:', '0.27518']
# ['epoch', ':', '5', 'iter', ':', '11', 'loss:', '1.58823', 'dice:', '0.22945']
# ['epoch', ':', '5', 'iter', ':', '11', 'loss:', '1.49817', 'dice:', '0.28989']
# ['epoch', ':', '5', 'iter', ':', '11', 'loss:', '1.53089', 'dice:', '0.26942']
# ['epoch', ':', '5', 'iter', ':', '11', 'loss:', '1.52513', 'dice:', '0.28534']
# ['epoch', ':', '5', 'iter', ':', '12', 'loss:', '1.48708', 'dice:', '0.30313']
# ['epoch', ':', '5', 'iter', ':', '12', 'loss:', '1.97114', 'dice:', '0.04718']
# ['epoch', ':', '5', 'iter', ':', '12', 'loss:', '1.90335', 'dice:', '0.12123']
# ['epoch', ':', '5', 'iter', ':', '12', 'loss:', '1.32807', 'dice:', '0.45648']
# ['epoch', ':', '6', 'iter', ':', '0', 'loss:', '1.46585', 'dice:', '0.31379']
# ['epoch', ':', '6', 'iter', ':', '0', 'loss:', '1.55752', 'dice:', '0.25074']
# ['epoch', ':', '6', 'iter', ':', '0', 'loss:', '1.52604', 'dice:', '0.28620']
# ['epoch', ':', '6', 'iter', ':', '0', 'loss:', '1.57000', 'dice:', '0.24293']
# ['epoch', ':', '6', 'iter', ':', '1', 'loss:', '1.53540', 'dice:', '0.28651']
# ['epoch', ':', '6', 'iter', ':', '1', 'loss:', '1.57189', 'dice:', '0.22944']
# ['epoch', ':', '6', 'iter', ':', '1', 'loss:', '1.57637', 'dice:', '0.23819']
# ['epoch', ':', '6', 'iter', ':', '1', 'loss:', '1.53577', 'dice:', '0.27111']
# ['epoch', ':', '6', 'iter', ':', '2', 'loss:', '1.58493', 'dice:', '0.24792']
# ['epoch', ':', '6', 'iter', ':', '2', 'loss:', '1.59287', 'dice:', '0.22362']
# ['epoch', ':', '6', 'iter', ':', '2', 'loss:', '1.51853', 'dice:', '0.28215']
# ['epoch', ':', '6', 'iter', ':', '2', 'loss:', '1.54276', 'dice:', '0.25982']
# ['epoch', ':', '6', 'iter', ':', '3', 'loss:', '1.56625', 'dice:', '0.24334']
# ['epoch', ':', '6', 'iter', ':', '3', 'loss:', '1.59726', 'dice:', '0.21928']
# ['epoch', ':', '6', 'iter', ':', '3', 'loss:', '1.56523', 'dice:', '0.23563']
# ['epoch', ':', '6', 'iter', ':', '3', 'loss:', '1.57154', 'dice:', '0.23359']
# ['epoch', ':', '6', 'iter', ':', '4', 'loss:', '1.62590', 'dice:', '0.21427']
# ['epoch', ':', '6', 'iter', ':', '4', 'loss:', '1.49840', 'dice:', '0.30527']
# ['epoch', ':', '6', 'iter', ':', '4', 'loss:', '1.56032', 'dice:', '0.24114']
# ['epoch', ':', '6', 'iter', ':', '4', 'loss:', '1.62503', 'dice:', '0.19797']
# ['epoch', ':', '6', 'iter', ':', '5', 'loss:', '1.64127', 'dice:', '0.16513']
# ['epoch', ':', '6', 'iter', ':', '5', 'loss:', '1.43548', 'dice:', '0.33677']
# ['epoch', ':', '6', 'iter', ':', '5', 'loss:', '1.60098', 'dice:', '0.21539']
# ['epoch', ':', '6', 'iter', ':', '5', 'loss:', '1.57551', 'dice:', '0.25637']
# ['epoch', ':', '6', 'iter', ':', '6', 'loss:', '1.55222', 'dice:', '0.24409']
# ['epoch', ':', '6', 'iter', ':', '6', 'loss:', '1.52955', 'dice:', '0.27356']
# ['epoch', ':', '6', 'iter', ':', '6', 'loss:', '1.54074', 'dice:', '0.27027']
# ['epoch', ':', '6', 'iter', ':', '6', 'loss:', '1.63509', 'dice:', '0.20149']
# ['epoch', ':', '6', 'iter', ':', '7', 'loss:', '1.58654', 'dice:', '0.20985']
# ['epoch', ':', '6', 'iter', ':', '7', 'loss:', '1.51388', 'dice:', '0.27350']
# ['epoch', ':', '6', 'iter', ':', '7', 'loss:', '1.63435', 'dice:', '0.18734']
# ['epoch', ':', '6', 'iter', ':', '7', 'loss:', '1.52613', 'dice:', '0.26001']
# ['epoch', ':', '6', 'iter', ':', '8', 'loss:', '1.52519', 'dice:', '0.27016']
# ['epoch', ':', '6', 'iter', ':', '8', 'loss:', '1.56322', 'dice:', '0.22813']
# ['epoch', ':', '6', 'iter', ':', '8', 'loss:', '1.54381', 'dice:', '0.25152']
# ['epoch', ':', '6', 'iter', ':', '8', 'loss:', '1.50897', 'dice:', '0.26813']
# ['epoch', ':', '6', 'iter', ':', '9', 'loss:', '1.61308', 'dice:', '0.20285']
# ['epoch', ':', '6', 'iter', ':', '9', 'loss:', '1.54285', 'dice:', '0.24640']
# ['epoch', ':', '6', 'iter', ':', '9', 'loss:', '1.45862', 'dice:', '0.31288']
# ['epoch', ':', '6', 'iter', ':', '9', 'loss:', '1.39274', 'dice:', '0.36030']
# ['epoch', ':', '6', 'iter', ':', '10', 'loss:', '1.48627', 'dice:', '0.29322']
# ['epoch', ':', '6', 'iter', ':', '10', 'loss:', '1.44463', 'dice:', '0.32209']
# ['epoch', ':', '6', 'iter', ':', '10', 'loss:', '1.52929', 'dice:', '0.26555']
# ['epoch', ':', '6', 'iter', ':', '10', 'loss:', '1.50427', 'dice:', '0.27892']
# ['epoch', ':', '6', 'iter', ':', '11', 'loss:', '1.47442', 'dice:', '0.28232']
# ['epoch', ':', '6', 'iter', ':', '11', 'loss:', '1.60496', 'dice:', '0.19703']
# ['epoch', ':', '6', 'iter', ':', '11', 'loss:', '1.67293', 'dice:', '0.17437']
# ['epoch', ':', '6', 'iter', ':', '11', 'loss:', '1.51924', 'dice:', '0.27703']
# ['epoch', ':', '6', 'iter', ':', '12', 'loss:', '1.72408', 'dice:', '0.21097']
# ['epoch', ':', '6', 'iter', ':', '12', 'loss:', '1.84776', 'dice:', '0.16518']
# ['epoch', ':', '6', 'iter', ':', '12', 'loss:', '1.42392', 'dice:', '0.34762']
# ['epoch', ':', '6', 'iter', ':', '12', 'loss:', '1.41590', 'dice:', '0.37869']
# ['epoch', ':', '7', 'iter', ':', '0', 'loss:', '1.48257', 'dice:', '0.28488']
# ['epoch', ':', '7', 'iter', ':', '0', 'loss:', '1.48380', 'dice:', '0.28674']
# ['epoch', ':', '7', 'iter', ':', '0', 'loss:', '1.49975', 'dice:', '0.30002']
# ['epoch', ':', '7', 'iter', ':', '0', 'loss:', '1.43801', 'dice:', '0.32355']
# ['epoch', ':', '7', 'iter', ':', '1', 'loss:', '1.52886', 'dice:', '0.26791']
# ['epoch', ':', '7', 'iter', ':', '1', 'loss:', '1.45607', 'dice:', '0.30047']
# ['epoch', ':', '7', 'iter', ':', '1', 'loss:', '1.52231', 'dice:', '0.25843']
# ['epoch', ':', '7', 'iter', ':', '1', 'loss:', '1.46633', 'dice:', '0.30962']
# ['epoch', ':', '7', 'iter', ':', '2', 'loss:', '1.55318', 'dice:', '0.24639']
# ['epoch', ':', '7', 'iter', ':', '2', 'loss:', '1.53057', 'dice:', '0.23801']
# ['epoch', ':', '7', 'iter', ':', '2', 'loss:', '1.54671', 'dice:', '0.24948']
# ['epoch', ':', '7', 'iter', ':', '2', 'loss:', '1.50574', 'dice:', '0.25519']
# ['epoch', ':', '7', 'iter', ':', '3', 'loss:', '1.60104', 'dice:', '0.20904']
# ['epoch', ':', '7', 'iter', ':', '3', 'loss:', '1.49755', 'dice:', '0.26058']
# ['epoch', ':', '7', 'iter', ':', '3', 'loss:', '1.48903', 'dice:', '0.28107']
# ['epoch', ':', '7', 'iter', ':', '3', 'loss:', '1.42483', 'dice:', '0.31530']
# ['epoch', ':', '7', 'iter', ':', '4', 'loss:', '1.58642', 'dice:', '0.20357']
# ['epoch', ':', '7', 'iter', ':', '4', 'loss:', '1.52386', 'dice:', '0.24710']
# ['epoch', ':', '7', 'iter', ':', '4', 'loss:', '1.53256', 'dice:', '0.23030']
# ['epoch', ':', '7', 'iter', ':', '4', 'loss:', '1.42294', 'dice:', '0.33718']
# ['epoch', ':', '7', 'iter', ':', '5', 'loss:', '1.54969', 'dice:', '0.23357']
# ['epoch', ':', '7', 'iter', ':', '5', 'loss:', '1.39574', 'dice:', '0.33654']
# ['epoch', ':', '7', 'iter', ':', '5', 'loss:', '1.45987', 'dice:', '0.30184']
# ['epoch', ':', '7', 'iter', ':', '5', 'loss:', '1.62526', 'dice:', '0.19149']
# ['epoch', ':', '7', 'iter', ':', '6', 'loss:', '1.54490', 'dice:', '0.22807']
# ['epoch', ':', '7', 'iter', ':', '6', 'loss:', '1.46978', 'dice:', '0.28491']
# ['epoch', ':', '7', 'iter', ':', '6', 'loss:', '1.52856', 'dice:', '0.23736']
# ['epoch', ':', '7', 'iter', ':', '6', 'loss:', '1.51959', 'dice:', '0.24468']
# ['epoch', ':', '7', 'iter', ':', '7', 'loss:', '1.53937', 'dice:', '0.25855']
# ['epoch', ':', '7', 'iter', ':', '7', 'loss:', '1.37579', 'dice:', '0.36580']
# ['epoch', ':', '7', 'iter', ':', '7', 'loss:', '1.52751', 'dice:', '0.26008']
# ['epoch', ':', '7', 'iter', ':', '7', 'loss:', '1.46699', 'dice:', '0.30468']
# ['epoch', ':', '7', 'iter', ':', '8', 'loss:', '1.51539', 'dice:', '0.26910']
# ['epoch', ':', '7', 'iter', ':', '8', 'loss:', '1.44041', 'dice:', '0.31838']
# ['epoch', ':', '7', 'iter', ':', '8', 'loss:', '1.38303', 'dice:', '0.33653']
# ['epoch', ':', '7', 'iter', ':', '8', 'loss:', '1.48401', 'dice:', '0.27958']
# ['epoch', ':', '7', 'iter', ':', '9', 'loss:', '1.42701', 'dice:', '0.30538']
# ['epoch', ':', '7', 'iter', ':', '9', 'loss:', '1.56791', 'dice:', '0.23125']
# ['epoch', ':', '7', 'iter', ':', '9', 'loss:', '1.52775', 'dice:', '0.26803']
# ['epoch', ':', '7', 'iter', ':', '9', 'loss:', '1.49699', 'dice:', '0.27098']
# ['epoch', ':', '7', 'iter', ':', '10', 'loss:', '1.53509', 'dice:', '0.24991']
# ['epoch', ':', '7', 'iter', ':', '10', 'loss:', '1.47419', 'dice:', '0.28516']
# ['epoch', ':', '7', 'iter', ':', '10', 'loss:', '1.42425', 'dice:', '0.32133']
# ['epoch', ':', '7', 'iter', ':', '10', 'loss:', '1.48990', 'dice:', '0.25560']
# ['epoch', ':', '7', 'iter', ':', '11', 'loss:', '1.44922', 'dice:', '0.30598']
# ['epoch', ':', '7', 'iter', ':', '11', 'loss:', '1.45624', 'dice:', '0.28677']
# ['epoch', ':', '7', 'iter', ':', '11', 'loss:', '1.50205', 'dice:', '0.27502']
# ['epoch', ':', '7', 'iter', ':', '11', 'loss:', '1.37437', 'dice:', '0.35645']
# ['epoch', ':', '7', 'iter', ':', '12', 'loss:', '1.79998', 'dice:', '0.14962']
# ['epoch', ':', '7', 'iter', ':', '12', 'loss:', '1.53317', 'dice:', '0.24634']
# ['epoch', ':', '7', 'iter', ':', '12', 'loss:', '1.46972', 'dice:', '0.28289']
# ['epoch', ':', '7', 'iter', ':', '12', 'loss:', '1.17662', 'dice:', '0.53429']
# ['epoch', ':', '8', 'iter', ':', '0', 'loss:', '1.58784', 'dice:', '0.19295']
# ['epoch', ':', '8', 'iter', ':', '0', 'loss:', '1.49124', 'dice:', '0.26538']
# ['epoch', ':', '8', 'iter', ':', '0', 'loss:', '1.55226', 'dice:', '0.20919']
# ['epoch', ':', '8', 'iter', ':', '0', 'loss:', '1.40365', 'dice:', '0.33780']
# ['epoch', ':', '8', 'iter', ':', '1', 'loss:', '1.50962', 'dice:', '0.26958']
# ['epoch', ':', '8', 'iter', ':', '1', 'loss:', '1.56458', 'dice:', '0.22252']
# ['epoch', ':', '8', 'iter', ':', '1', 'loss:', '1.49822', 'dice:', '0.27927']
# ['epoch', ':', '8', 'iter', ':', '1', 'loss:', '1.47595', 'dice:', '0.26032']
# ['epoch', ':', '8', 'iter', ':', '2', 'loss:', '1.49452', 'dice:', '0.26523']
# ['epoch', ':', '8', 'iter', ':', '2', 'loss:', '1.47472', 'dice:', '0.27604']
# ['epoch', ':', '8', 'iter', ':', '2', 'loss:', '1.41431', 'dice:', '0.30641']
# ['epoch', ':', '8', 'iter', ':', '2', 'loss:', '1.44684', 'dice:', '0.30782']
# ['epoch', ':', '8', 'iter', ':', '3', 'loss:', '1.57955', 'dice:', '0.20400']
# ['epoch', ':', '8', 'iter', ':', '3', 'loss:', '1.45076', 'dice:', '0.29646']
# ['epoch', ':', '8', 'iter', ':', '3', 'loss:', '1.45927', 'dice:', '0.29302']
# ['epoch', ':', '8', 'iter', ':', '3', 'loss:', '1.53023', 'dice:', '0.24017']
# ['epoch', ':', '8', 'iter', ':', '4', 'loss:', '1.43662', 'dice:', '0.30499']
# ['epoch', ':', '8', 'iter', ':', '4', 'loss:', '1.43411', 'dice:', '0.29730']
# ['epoch', ':', '8', 'iter', ':', '4', 'loss:', '1.43291', 'dice:', '0.31051']
# ['epoch', ':', '8', 'iter', ':', '4', 'loss:', '1.59828', 'dice:', '0.19138']
# ['epoch', ':', '8', 'iter', ':', '5', 'loss:', '1.34992', 'dice:', '0.38330']
# ['epoch', ':', '8', 'iter', ':', '5', 'loss:', '1.41289', 'dice:', '0.32156']
# ['epoch', ':', '8', 'iter', ':', '5', 'loss:', '1.46996', 'dice:', '0.25564']
# ['epoch', ':', '8', 'iter', ':', '5', 'loss:', '1.50228', 'dice:', '0.25189']
# ['epoch', ':', '8', 'iter', ':', '6', 'loss:', '1.44511', 'dice:', '0.29305']
# ['epoch', ':', '8', 'iter', ':', '6', 'loss:', '1.53240', 'dice:', '0.24526']
# ['epoch', ':', '8', 'iter', ':', '6', 'loss:', '1.50177', 'dice:', '0.23829']
# ['epoch', ':', '8', 'iter', ':', '6', 'loss:', '1.51495', 'dice:', '0.25645']
# ['epoch', ':', '8', 'iter', ':', '7', 'loss:', '1.38899', 'dice:', '0.34576']
# ['epoch', ':', '8', 'iter', ':', '7', 'loss:', '1.42517', 'dice:', '0.30871']
# ['epoch', ':', '8', 'iter', ':', '7', 'loss:', '1.48560', 'dice:', '0.27300']
# ['epoch', ':', '8', 'iter', ':', '7', 'loss:', '1.55482', 'dice:', '0.20717']
# ['epoch', ':', '8', 'iter', ':', '8', 'loss:', '1.39610', 'dice:', '0.31169']
# ['epoch', ':', '8', 'iter', ':', '8', 'loss:', '1.49396', 'dice:', '0.25641']
# ['epoch', ':', '8', 'iter', ':', '8', 'loss:', '1.48098', 'dice:', '0.24890']
# ['epoch', ':', '8', 'iter', ':', '8', 'loss:', '1.38723', 'dice:', '0.32989']
# ['epoch', ':', '8', 'iter', ':', '9', 'loss:', '1.46522', 'dice:', '0.28778']
# ['epoch', ':', '8', 'iter', ':', '9', 'loss:', '1.48544', 'dice:', '0.25043']
# ['epoch', ':', '8', 'iter', ':', '9', 'loss:', '1.44200', 'dice:', '0.28399']
# ['epoch', ':', '8', 'iter', ':', '9', 'loss:', '1.45021', 'dice:', '0.27671']
# ['epoch', ':', '8', 'iter', ':', '10', 'loss:', '1.47935', 'dice:', '0.28179']
# ['epoch', ':', '8', 'iter', ':', '10', 'loss:', '1.44491', 'dice:', '0.27789']
# ['epoch', ':', '8', 'iter', ':', '10', 'loss:', '1.37175', 'dice:', '0.35060']
# ['epoch', ':', '8', 'iter', ':', '10', 'loss:', '1.48521', 'dice:', '0.26053']
# ['epoch', ':', '8', 'iter', ':', '11', 'loss:', '1.38055', 'dice:', '0.34551']
# ['epoch', ':', '8', 'iter', ':', '11', 'loss:', '1.44580', 'dice:', '0.29120']
# ['epoch', ':', '8', 'iter', ':', '11', 'loss:', '1.38638', 'dice:', '0.33135']
# ['epoch', ':', '8', 'iter', ':', '11', 'loss:', '1.47367', 'dice:', '0.26808']
# ['epoch', ':', '8', 'iter', ':', '12', 'loss:', '1.84469', 'dice:', '0.09631']
# ['epoch', ':', '8', 'iter', ':', '12', 'loss:', '1.58348', 'dice:', '0.19524']
# ['epoch', ':', '8', 'iter', ':', '12', 'loss:', '1.43280', 'dice:', '0.29126']
# ['epoch', ':', '8', 'iter', ':', '12', 'loss:', '1.31722', 'dice:', '0.38215']
# ['epoch', ':', '9', 'iter', ':', '0', 'loss:', '1.46834', 'dice:', '0.27947']
# ['epoch', ':', '9', 'iter', ':', '0', 'loss:', '1.43828', 'dice:', '0.30573']
# ['epoch', ':', '9', 'iter', ':', '0', 'loss:', '1.37110', 'dice:', '0.33396']
# ['epoch', ':', '9', 'iter', ':', '0', 'loss:', '1.41434', 'dice:', '0.30654']
# ['epoch', ':', '9', 'iter', ':', '1', 'loss:', '1.43629', 'dice:', '0.29157']
# ['epoch', ':', '9', 'iter', ':', '1', 'loss:', '1.46534', 'dice:', '0.25662']
# ['epoch', ':', '9', 'iter', ':', '1', 'loss:', '1.44139', 'dice:', '0.29617']
# ['epoch', ':', '9', 'iter', ':', '1', 'loss:', '1.50415', 'dice:', '0.24368']
# ['epoch', ':', '9', 'iter', ':', '2', 'loss:', '1.41032', 'dice:', '0.29696']
# ['epoch', ':', '9', 'iter', ':', '2', 'loss:', '1.51930', 'dice:', '0.23005']
# ['epoch', ':', '9', 'iter', ':', '2', 'loss:', '1.53167', 'dice:', '0.23664']
# ['epoch', ':', '9', 'iter', ':', '2', 'loss:', '1.52541', 'dice:', '0.23284']
# ['epoch', ':', '9', 'iter', ':', '3', 'loss:', '1.40278', 'dice:', '0.30132']
# ['epoch', ':', '9', 'iter', ':', '3', 'loss:', '1.44184', 'dice:', '0.28463']
# ['epoch', ':', '9', 'iter', ':', '3', 'loss:', '1.39137', 'dice:', '0.31587']
# ['epoch', ':', '9', 'iter', ':', '3', 'loss:', '1.39915', 'dice:', '0.31467']
# ['epoch', ':', '9', 'iter', ':', '4', 'loss:', '1.42601', 'dice:', '0.30760']
# ['epoch', ':', '9', 'iter', ':', '4', 'loss:', '1.43590', 'dice:', '0.30190']
# ['epoch', ':', '9', 'iter', ':', '4', 'loss:', '1.53732', 'dice:', '0.23120']
# ['epoch', ':', '9', 'iter', ':', '4', 'loss:', '1.36557', 'dice:', '0.34237']
# ['epoch', ':', '9', 'iter', ':', '5', 'loss:', '1.47552', 'dice:', '0.26232']
# ['epoch', ':', '9', 'iter', ':', '5', 'loss:', '1.39162', 'dice:', '0.31975']
# ['epoch', ':', '9', 'iter', ':', '5', 'loss:', '1.34573', 'dice:', '0.35786']
# ['epoch', ':', '9', 'iter', ':', '5', 'loss:', '1.51626', 'dice:', '0.24493']
# ['epoch', ':', '9', 'iter', ':', '6', 'loss:', '1.41804', 'dice:', '0.28536']
# ['epoch', ':', '9', 'iter', ':', '6', 'loss:', '1.39181', 'dice:', '0.30993']
# ['epoch', ':', '9', 'iter', ':', '6', 'loss:', '1.37744', 'dice:', '0.32468']
# ['epoch', ':', '9', 'iter', ':', '6', 'loss:', '1.45139', 'dice:', '0.27565']
# ['epoch', ':', '9', 'iter', ':', '7', 'loss:', '1.43405', 'dice:', '0.27623']
# ['epoch', ':', '9', 'iter', ':', '7', 'loss:', '1.37776', 'dice:', '0.33092']
# ['epoch', ':', '9', 'iter', ':', '7', 'loss:', '1.44467', 'dice:', '0.27493']
# ['epoch', ':', '9', 'iter', ':', '7', 'loss:', '1.46417', 'dice:', '0.25249']
# ['epoch', ':', '9', 'iter', ':', '8', 'loss:', '1.44589', 'dice:', '0.29696']
# ['epoch', ':', '9', 'iter', ':', '8', 'loss:', '1.49110', 'dice:', '0.24185']
# ['epoch', ':', '9', 'iter', ':', '8', 'loss:', '1.44427', 'dice:', '0.26443']
# ['epoch', ':', '9', 'iter', ':', '8', 'loss:', '1.47462', 'dice:', '0.25525']
# ['epoch', ':', '9', 'iter', ':', '9', 'loss:', '1.38762', 'dice:', '0.33295']
# ['epoch', ':', '9', 'iter', ':', '9', 'loss:', '1.41887', 'dice:', '0.29725']
# ['epoch', ':', '9', 'iter', ':', '9', 'loss:', '1.49096', 'dice:', '0.26865']
# ['epoch', ':', '9', 'iter', ':', '9', 'loss:', '1.50480', 'dice:', '0.22383']
# ['epoch', ':', '9', 'iter', ':', '10', 'loss:', '1.40310', 'dice:', '0.29471']
# ['epoch', ':', '9', 'iter', ':', '10', 'loss:', '1.33822', 'dice:', '0.35302']
# ['epoch', ':', '9', 'iter', ':', '10', 'loss:', '1.41184', 'dice:', '0.30188']
# ['epoch', ':', '9', 'iter', ':', '10', 'loss:', '1.32991', 'dice:', '0.36530']
# ['epoch', ':', '9', 'iter', ':', '11', 'loss:', '1.53037', 'dice:', '0.22783']
# ['epoch', ':', '9', 'iter', ':', '11', 'loss:', '1.57585', 'dice:', '0.16820']
# ['epoch', ':', '9', 'iter', ':', '11', 'loss:', '1.38073', 'dice:', '0.32890']
# ['epoch', ':', '9', 'iter', ':', '11', 'loss:', '1.34277', 'dice:', '0.34995']
# ['epoch', ':', '9', 'iter', ':', '12', 'loss:', '1.52135', 'dice:', '0.24773']
# ['epoch', ':', '9', 'iter', ':', '12', 'loss:', '1.44589', 'dice:', '0.22398']
# ['epoch', ':', '9', 'iter', ':', '12', 'loss:', '1.66093', 'dice:', '0.13971']
# ['epoch', ':', '9', 'iter', ':', '12', 'loss:', '1.63133', 'dice:', '0.19550']
# ['epoch', ':', '10', 'iter', ':', '0', 'loss:', '1.37317', 'dice:', '0.32176']
# ['epoch', ':', '10', 'iter', ':', '0', 'loss:', '1.36397', 'dice:', '0.34440']
# ['epoch', ':', '10', 'iter', ':', '0', 'loss:', '1.46930', 'dice:', '0.27052']
# ['epoch', ':', '10', 'iter', ':', '0', 'loss:', '1.35196', 'dice:', '0.33602']
# ['epoch', ':', '10', 'iter', ':', '1', 'loss:', '1.42717', 'dice:', '0.30084']
# ['epoch', ':', '10', 'iter', ':', '1', 'loss:', '1.36899', 'dice:', '0.33955']
# ['epoch', ':', '10', 'iter', ':', '1', 'loss:', '1.43047', 'dice:', '0.27169']
# ['epoch', ':', '10', 'iter', ':', '1', 'loss:', '1.39118', 'dice:', '0.32776']
# ['epoch', ':', '10', 'iter', ':', '2', 'loss:', '1.40688', 'dice:', '0.30127']
# ['epoch', ':', '10', 'iter', ':', '2', 'loss:', '1.29906', 'dice:', '0.40243']
# ['epoch', ':', '10', 'iter', ':', '2', 'loss:', '1.39676', 'dice:', '0.29843']
# ['epoch', ':', '10', 'iter', ':', '2', 'loss:', '1.40997', 'dice:', '0.29672']
# ['epoch', ':', '10', 'iter', ':', '3', 'loss:', '1.50030', 'dice:', '0.24003']
# ['epoch', ':', '10', 'iter', ':', '3', 'loss:', '1.48827', 'dice:', '0.24752']
# ['epoch', ':', '10', 'iter', ':', '3', 'loss:', '1.49990', 'dice:', '0.23749']
# ['epoch', ':', '10', 'iter', ':', '3', 'loss:', '1.43902', 'dice:', '0.27661']
# ['epoch', ':', '10', 'iter', ':', '4', 'loss:', '1.47578', 'dice:', '0.23728']
# ['epoch', ':', '10', 'iter', ':', '4', 'loss:', '1.48728', 'dice:', '0.25267']
# ['epoch', ':', '10', 'iter', ':', '4', 'loss:', '1.39024', 'dice:', '0.29195']
# ['epoch', ':', '10', 'iter', ':', '4', 'loss:', '1.39996', 'dice:', '0.31668']
# ['epoch', ':', '10', 'iter', ':', '5', 'loss:', '1.45996', 'dice:', '0.25457']
# ['epoch', ':', '10', 'iter', ':', '5', 'loss:', '1.39317', 'dice:', '0.28566']
# ['epoch', ':', '10', 'iter', ':', '5', 'loss:', '1.37766', 'dice:', '0.32452']
# ['epoch', ':', '10', 'iter', ':', '5', 'loss:', '1.39103', 'dice:', '0.29583']
# ['epoch', ':', '10', 'iter', ':', '6', 'loss:', '1.37107', 'dice:', '0.31209']
# ['epoch', ':', '10', 'iter', ':', '6', 'loss:', '1.43429', 'dice:', '0.27279']
# ['epoch', ':', '10', 'iter', ':', '6', 'loss:', '1.34641', 'dice:', '0.34390']
# ['epoch', ':', '10', 'iter', ':', '6', 'loss:', '1.58305', 'dice:', '0.16504']
# ['epoch', ':', '10', 'iter', ':', '7', 'loss:', '1.47112', 'dice:', '0.24668']
# ['epoch', ':', '10', 'iter', ':', '7', 'loss:', '1.35039', 'dice:', '0.34240']
# ['epoch', ':', '10', 'iter', ':', '7', 'loss:', '1.42623', 'dice:', '0.27215']
# ['epoch', ':', '10', 'iter', ':', '7', 'loss:', '1.38770', 'dice:', '0.31719']
# ['epoch', ':', '10', 'iter', ':', '8', 'loss:', '1.38595', 'dice:', '0.30659']
# ['epoch', ':', '10', 'iter', ':', '8', 'loss:', '1.38757', 'dice:', '0.30637']
# ['epoch', ':', '10', 'iter', ':', '8', 'loss:', '1.39764', 'dice:', '0.29457']
# ['epoch', ':', '10', 'iter', ':', '8', 'loss:', '1.45666', 'dice:', '0.24281']
# ['epoch', ':', '10', 'iter', ':', '9', 'loss:', '1.41076', 'dice:', '0.29908']
# ['epoch', ':', '10', 'iter', ':', '9', 'loss:', '1.48820', 'dice:', '0.25388']
# ['epoch', ':', '10', 'iter', ':', '9', 'loss:', '1.45437', 'dice:', '0.26090']
# ['epoch', ':', '10', 'iter', ':', '9', 'loss:', '1.36417', 'dice:', '0.30773']
# ['epoch', ':', '10', 'iter', ':', '10', 'loss:', '1.32609', 'dice:', '0.35610']
# ['epoch', ':', '10', 'iter', ':', '10', 'loss:', '1.45669', 'dice:', '0.26927']
# ['epoch', ':', '10', 'iter', ':', '10', 'loss:', '1.29842', 'dice:', '0.37148']
# ['epoch', ':', '10', 'iter', ':', '10', 'loss:', '1.28650', 'dice:', '0.40493']
# ['epoch', ':', '10', 'iter', ':', '11', 'loss:', '1.40951', 'dice:', '0.29421']
# ['epoch', ':', '10', 'iter', ':', '11', 'loss:', '1.31271', 'dice:', '0.36019']
# ['epoch', ':', '10', 'iter', ':', '11', 'loss:', '1.42087', 'dice:', '0.27827']
# ['epoch', ':', '10', 'iter', ':', '11', 'loss:', '1.32452', 'dice:', '0.35960']
# ['epoch', ':', '10', 'iter', ':', '12', 'loss:', '1.54043', 'dice:', '0.24022']
# ['epoch', ':', '10', 'iter', ':', '12', 'loss:', '1.18286', 'dice:', '0.51752']
# ['epoch', ':', '10', 'iter', ':', '12', 'loss:', '1.90460', 'dice:', '0.03317']
# ['epoch', ':', '10', 'iter', ':', '12', 'loss:', '1.21414', 'dice:', '0.48314']
# ['epoch', ':', '11', 'iter', ':', '0', 'loss:', '1.43524', 'dice:', '0.26881']
# ['epoch', ':', '11', 'iter', ':', '0', 'loss:', '1.40589', 'dice:', '0.29360']
# ['epoch', ':', '11', 'iter', ':', '0', 'loss:', '1.50052', 'dice:', '0.23713']
# ['epoch', ':', '11', 'iter', ':', '0', 'loss:', '1.36521', 'dice:', '0.32456']
# ['epoch', ':', '11', 'iter', ':', '1', 'loss:', '1.30194', 'dice:', '0.36770']
# ['epoch', ':', '11', 'iter', ':', '1', 'loss:', '1.36034', 'dice:', '0.31785']
# ['epoch', ':', '11', 'iter', ':', '1', 'loss:', '1.46113', 'dice:', '0.24619']
# ['epoch', ':', '11', 'iter', ':', '1', 'loss:', '1.54591', 'dice:', '0.18233']
# ['epoch', ':', '11', 'iter', ':', '2', 'loss:', '1.31569', 'dice:', '0.37161']
# ['epoch', ':', '11', 'iter', ':', '2', 'loss:', '1.46103', 'dice:', '0.23011']
# ['epoch', ':', '11', 'iter', ':', '2', 'loss:', '1.32902', 'dice:', '0.34394']
# ['epoch', ':', '11', 'iter', ':', '2', 'loss:', '1.32929', 'dice:', '0.33666']
# ['epoch', ':', '11', 'iter', ':', '3', 'loss:', '1.39478', 'dice:', '0.28802']
# ['epoch', ':', '11', 'iter', ':', '3', 'loss:', '1.28353', 'dice:', '0.38392']
# ['epoch', ':', '11', 'iter', ':', '3', 'loss:', '1.33383', 'dice:', '0.34946']
# ['epoch', ':', '11', 'iter', ':', '3', 'loss:', '1.37899', 'dice:', '0.30788']
# ['epoch', ':', '11', 'iter', ':', '4', 'loss:', '1.37851', 'dice:', '0.30007']
# ['epoch', ':', '11', 'iter', ':', '4', 'loss:', '1.44303', 'dice:', '0.27254']
# ['epoch', ':', '11', 'iter', ':', '4', 'loss:', '1.44618', 'dice:', '0.23383']
# ['epoch', ':', '11', 'iter', ':', '4', 'loss:', '1.37436', 'dice:', '0.31989']
# ['epoch', ':', '11', 'iter', ':', '5', 'loss:', '1.43181', 'dice:', '0.27263']
# ['epoch', ':', '11', 'iter', ':', '5', 'loss:', '1.35413', 'dice:', '0.33443']
# ['epoch', ':', '11', 'iter', ':', '5', 'loss:', '1.37471', 'dice:', '0.31429']
# ['epoch', ':', '11', 'iter', ':', '5', 'loss:', '1.40188', 'dice:', '0.27103']
# ['epoch', ':', '11', 'iter', ':', '6', 'loss:', '1.34403', 'dice:', '0.33649']
# ['epoch', ':', '11', 'iter', ':', '6', 'loss:', '1.43432', 'dice:', '0.26636']
# ['epoch', ':', '11', 'iter', ':', '6', 'loss:', '1.36080', 'dice:', '0.31731']
# ['epoch', ':', '11', 'iter', ':', '6', 'loss:', '1.37462', 'dice:', '0.30572']
# ['epoch', ':', '11', 'iter', ':', '7', 'loss:', '1.39286', 'dice:', '0.28489']
# ['epoch', ':', '11', 'iter', ':', '7', 'loss:', '1.36246', 'dice:', '0.31110']
# ['epoch', ':', '11', 'iter', ':', '7', 'loss:', '1.37438', 'dice:', '0.32271']
# ['epoch', ':', '11', 'iter', ':', '7', 'loss:', '1.28202', 'dice:', '0.37350']
# ['epoch', ':', '11', 'iter', ':', '8', 'loss:', '1.47692', 'dice:', '0.24552']
# ['epoch', ':', '11', 'iter', ':', '8', 'loss:', '1.46067', 'dice:', '0.24248']
# ['epoch', ':', '11', 'iter', ':', '8', 'loss:', '1.25801', 'dice:', '0.40288']
# ['epoch', ':', '11', 'iter', ':', '8', 'loss:', '1.45761', 'dice:', '0.23275']
# ['epoch', ':', '11', 'iter', ':', '9', 'loss:', '1.40853', 'dice:', '0.28482']
# ['epoch', ':', '11', 'iter', ':', '9', 'loss:', '1.24224', 'dice:', '0.39942']
# ['epoch', ':', '11', 'iter', ':', '9', 'loss:', '1.39970', 'dice:', '0.29423']
# ['epoch', ':', '11', 'iter', ':', '9', 'loss:', '1.42901', 'dice:', '0.26342']
# ...
# ['epoch', ':', '197', 'iter', ':', '9', 'loss:', '0.65122', 'dice:', '0.49784']
# ['epoch', ':', '197', 'iter', ':', '9', 'loss:', '0.76610', 'dice:', '0.37364']
# ['epoch', ':', '197', 'iter', ':', '9', 'loss:', '0.65214', 'dice:', '0.49654']
# ['epoch', ':', '197', 'iter', ':', '10', 'loss:', '0.50139', 'dice:', '0.63625']
# ['epoch', ':', '197', 'iter', ':', '10', 'loss:', '0.54947', 'dice:', '0.58637']
# ['epoch', ':', '197', 'iter', ':', '10', 'loss:', '0.66572', 'dice:', '0.47150']
# ['epoch', ':', '197', 'iter', ':', '10', 'loss:', '0.74908', 'dice:', '0.38828']
# ['epoch', ':', '197', 'iter', ':', '11', 'loss:', '0.59099', 'dice:', '0.54919']
# ['epoch', ':', '197', 'iter', ':', '11', 'loss:', '0.67983', 'dice:', '0.46671']
# ['epoch', ':', '197', 'iter', ':', '11', 'loss:', '0.64307', 'dice:', '0.49118']
# ['epoch', ':', '197', 'iter', ':', '11', 'loss:', '0.66126', 'dice:', '0.48226']
# ['epoch', ':', '197', 'iter', ':', '12', 'loss:', '0.83793', 'dice:', '0.33677']
# ['epoch', ':', '197', 'iter', ':', '12', 'loss:', '0.46624', 'dice:', '0.73478']
# ['epoch', ':', '197', 'iter', ':', '12', 'loss:', '0.76755', 'dice:', '0.41632']
# ['epoch', ':', '197', 'iter', ':', '12', 'loss:', '0.72121', 'dice:', '0.42996']
# ['epoch', ':', '198', 'iter', ':', '0', 'loss:', '0.67422', 'dice:', '0.47188']
# ['epoch', ':', '198', 'iter', ':', '0', 'loss:', '0.67769', 'dice:', '0.45588']
# ['epoch', ':', '198', 'iter', ':', '0', 'loss:', '0.62396', 'dice:', '0.51288']
# ['epoch', ':', '198', 'iter', ':', '0', 'loss:', '0.60127', 'dice:', '0.53526']
# ['epoch', ':', '198', 'iter', ':', '1', 'loss:', '0.63972', 'dice:', '0.49111']
# ['epoch', ':', '198', 'iter', ':', '1', 'loss:', '0.65813', 'dice:', '0.47298']
# ['epoch', ':', '198', 'iter', ':', '1', 'loss:', '0.73329', 'dice:', '0.40671']
# ['epoch', ':', '198', 'iter', ':', '1', 'loss:', '0.70257', 'dice:', '0.44106']
# ['epoch', ':', '198', 'iter', ':', '2', 'loss:', '0.69968', 'dice:', '0.44048']
# ['epoch', ':', '198', 'iter', ':', '2', 'loss:', '0.70193', 'dice:', '0.43174']
# ['epoch', ':', '198', 'iter', ':', '2', 'loss:', '0.69186', 'dice:', '0.44217']
# ['epoch', ':', '198', 'iter', ':', '2', 'loss:', '0.63021', 'dice:', '0.51546']
# ['epoch', ':', '198', 'iter', ':', '3', 'loss:', '0.67422', 'dice:', '0.46863']
# ['epoch', ':', '198', 'iter', ':', '3', 'loss:', '0.72918', 'dice:', '0.41650']
# ['epoch', ':', '198', 'iter', ':', '3', 'loss:', '0.58289', 'dice:', '0.56126']
# ['epoch', ':', '198', 'iter', ':', '3', 'loss:', '0.64414', 'dice:', '0.48654']
# ['epoch', ':', '198', 'iter', ':', '4', 'loss:', '0.66709', 'dice:', '0.47059']
# ['epoch', ':', '198', 'iter', ':', '4', 'loss:', '0.64922', 'dice:', '0.49288']
# ['epoch', ':', '198', 'iter', ':', '4', 'loss:', '0.68286', 'dice:', '0.46945']
# ['epoch', ':', '198', 'iter', ':', '4', 'loss:', '0.80872', 'dice:', '0.32934']
# ['epoch', ':', '198', 'iter', ':', '5', 'loss:', '0.69882', 'dice:', '0.43248']
# ['epoch', ':', '198', 'iter', ':', '5', 'loss:', '0.73716', 'dice:', '0.40780']
# ['epoch', ':', '198', 'iter', ':', '5', 'loss:', '0.68917', 'dice:', '0.45642']
# ['epoch', ':', '198', 'iter', ':', '5', 'loss:', '0.63019', 'dice:', '0.52149']
# ['epoch', ':', '198', 'iter', ':', '6', 'loss:', '0.65177', 'dice:', '0.48897']
# ['epoch', ':', '198', 'iter', ':', '6', 'loss:', '0.67612', 'dice:', '0.46504']
# ['epoch', ':', '198', 'iter', ':', '6', 'loss:', '0.65487', 'dice:', '0.50099']
# ['epoch', ':', '198', 'iter', ':', '6', 'loss:', '0.62837', 'dice:', '0.51666']
# ['epoch', ':', '198', 'iter', ':', '7', 'loss:', '0.65430', 'dice:', '0.47042']
# ['epoch', ':', '198', 'iter', ':', '7', 'loss:', '0.80279', 'dice:', '0.32940']
# ['epoch', ':', '198', 'iter', ':', '7', 'loss:', '0.75793', 'dice:', '0.37389']
# ['epoch', ':', '198', 'iter', ':', '7', 'loss:', '0.58050', 'dice:', '0.54918']
# ['epoch', ':', '198', 'iter', ':', '8', 'loss:', '0.61674', 'dice:', '0.51953']
# ['epoch', ':', '198', 'iter', ':', '8', 'loss:', '0.58936', 'dice:', '0.54623']
# ['epoch', ':', '198', 'iter', ':', '8', 'loss:', '0.56024', 'dice:', '0.57827']
# ['epoch', ':', '198', 'iter', ':', '8', 'loss:', '0.58793', 'dice:', '0.55046']
# ['epoch', ':', '198', 'iter', ':', '9', 'loss:', '0.64442', 'dice:', '0.49644']
# ['epoch', ':', '198', 'iter', ':', '9', 'loss:', '0.67523', 'dice:', '0.45212']
# ['epoch', ':', '198', 'iter', ':', '9', 'loss:', '0.68536', 'dice:', '0.46100']
# ['epoch', ':', '198', 'iter', ':', '9', 'loss:', '0.54864', 'dice:', '0.59540']
# ['epoch', ':', '198', 'iter', ':', '10', 'loss:', '0.71944', 'dice:', '0.41866']
# ['epoch', ':', '198', 'iter', ':', '10', 'loss:', '0.65546', 'dice:', '0.48641']
# ['epoch', ':', '198', 'iter', ':', '10', 'loss:', '0.70297', 'dice:', '0.42970']
# ['epoch', ':', '198', 'iter', ':', '10', 'loss:', '0.65293', 'dice:', '0.48887']
# ['epoch', ':', '198', 'iter', ':', '11', 'loss:', '0.68102', 'dice:', '0.45467']
# ['epoch', ':', '198', 'iter', ':', '11', 'loss:', '0.77552', 'dice:', '0.35605']
# ['epoch', ':', '198', 'iter', ':', '11', 'loss:', '0.71040', 'dice:', '0.43693']
# ['epoch', ':', '198', 'iter', ':', '11', 'loss:', '0.63090', 'dice:', '0.50145']
# ['epoch', ':', '198', 'iter', ':', '12', 'loss:', '0.66534', 'dice:', '0.56511']
# ['epoch', ':', '198', 'iter', ':', '12', 'loss:', '0.67724', 'dice:', '0.47355']
# ['epoch', ':', '198', 'iter', ':', '12', 'loss:', '0.90485', 'dice:', '0.28292']
# ['epoch', ':', '198', 'iter', ':', '12', 'loss:', '0.93974', 'dice:', '0.23175']
# ['epoch', ':', '199', 'iter', ':', '0', 'loss:', '0.64048', 'dice:', '0.50867']
# ['epoch', ':', '199', 'iter', ':', '0', 'loss:', '0.67051', 'dice:', '0.46331']
# ['epoch', ':', '199', 'iter', ':', '0', 'loss:', '0.61462', 'dice:', '0.53493']
# ['epoch', ':', '199', 'iter', ':', '0', 'loss:', '0.69270', 'dice:', '0.44214']
# ['epoch', ':', '199', 'iter', ':', '1', 'loss:', '0.71654', 'dice:', '0.41812']
# ['epoch', ':', '199', 'iter', ':', '1', 'loss:', '0.58663', 'dice:', '0.55422']
# ['epoch', ':', '199', 'iter', ':', '1', 'loss:', '0.66088', 'dice:', '0.48453']
# ['epoch', ':', '199', 'iter', ':', '1', 'loss:', '0.58860', 'dice:', '0.55093']
# ['epoch', ':', '199', 'iter', ':', '2', 'loss:', '0.65761', 'dice:', '0.48820']
# ['epoch', ':', '199', 'iter', ':', '2', 'loss:', '0.75983', 'dice:', '0.37941']
# ['epoch', ':', '199', 'iter', ':', '2', 'loss:', '0.60722', 'dice:', '0.53012']
# ['epoch', ':', '199', 'iter', ':', '2', 'loss:', '0.73701', 'dice:', '0.41702']
# ['epoch', ':', '199', 'iter', ':', '3', 'loss:', '0.67787', 'dice:', '0.45983']
# ['epoch', ':', '199', 'iter', ':', '3', 'loss:', '0.61832', 'dice:', '0.51787']
# ['epoch', ':', '199', 'iter', ':', '3', 'loss:', '0.68600', 'dice:', '0.45362']
# ['epoch', ':', '199', 'iter', ':', '3', 'loss:', '0.71228', 'dice:', '0.41442']
# ['epoch', ':', '199', 'iter', ':', '4', 'loss:', '0.62112', 'dice:', '0.49899']
# ['epoch', ':', '199', 'iter', ':', '4', 'loss:', '0.71620', 'dice:', '0.44329']
# ['epoch', ':', '199', 'iter', ':', '4', 'loss:', '0.73727', 'dice:', '0.38970']
# ['epoch', ':', '199', 'iter', ':', '4', 'loss:', '0.67185', 'dice:', '0.45937']
# ['epoch', ':', '199', 'iter', ':', '5', 'loss:', '0.66583', 'dice:', '0.46489']
# ['epoch', ':', '199', 'iter', ':', '5', 'loss:', '0.63127', 'dice:', '0.49157']
# ['epoch', ':', '199', 'iter', ':', '5', 'loss:', '0.63227', 'dice:', '0.51021']
# ['epoch', ':', '199', 'iter', ':', '5', 'loss:', '0.65042', 'dice:', '0.48118']
# ['epoch', ':', '199', 'iter', ':', '6', 'loss:', '0.68733', 'dice:', '0.44676']
# ['epoch', ':', '199', 'iter', ':', '6', 'loss:', '0.64383', 'dice:', '0.47759']
# ['epoch', ':', '199', 'iter', ':', '6', 'loss:', '0.65844', 'dice:', '0.47898']
# ['epoch', ':', '199', 'iter', ':', '6', 'loss:', '0.73304', 'dice:', '0.39762']
# ['epoch', ':', '199', 'iter', ':', '7', 'loss:', '0.68955', 'dice:', '0.45108']
# ['epoch', ':', '199', 'iter', ':', '7', 'loss:', '0.63388', 'dice:', '0.49948']
# ['epoch', ':', '199', 'iter', ':', '7', 'loss:', '0.62652', 'dice:', '0.51789']
# ['epoch', ':', '199', 'iter', ':', '7', 'loss:', '0.68331', 'dice:', '0.45249']
# ['epoch', ':', '199', 'iter', ':', '8', 'loss:', '0.65489', 'dice:', '0.47220']
# ['epoch', ':', '199', 'iter', ':', '8', 'loss:', '0.60478', 'dice:', '0.53294']
# ['epoch', ':', '199', 'iter', ':', '8', 'loss:', '0.68933', 'dice:', '0.44994']
# ['epoch', ':', '199', 'iter', ':', '8', 'loss:', '0.64509', 'dice:', '0.49113']
# ['epoch', ':', '199', 'iter', ':', '9', 'loss:', '0.63291', 'dice:', '0.50359']
# ['epoch', ':', '199', 'iter', ':', '9', 'loss:', '0.68100', 'dice:', '0.45589']
# ['epoch', ':', '199', 'iter', ':', '9', 'loss:', '0.69075', 'dice:', '0.44250']
# ['epoch', ':', '199', 'iter', ':', '9', 'loss:', '0.66826', 'dice:', '0.46028']
# ['epoch', ':', '199', 'iter', ':', '10', 'loss:', '0.57651', 'dice:', '0.56315']
# ['epoch', ':', '199', 'iter', ':', '10', 'loss:', '0.61584', 'dice:', '0.52038']
# ['epoch', ':', '199', 'iter', ':', '10', 'loss:', '0.58809', 'dice:', '0.55181']
# ['epoch', ':', '199', 'iter', ':', '10', 'loss:', '0.53345', 'dice:', '0.61223']
# ['epoch', ':', '199', 'iter', ':', '11', 'loss:', '0.68986', 'dice:', '0.44245']
# ['epoch', ':', '199', 'iter', ':', '11', 'loss:', '0.59430', 'dice:', '0.54269']
# ['epoch', ':', '199', 'iter', ':', '11', 'loss:', '0.65837', 'dice:', '0.47709']
# ['epoch', ':', '199', 'iter', ':', '11', 'loss:', '0.73020', 'dice:', '0.41073']
# ['epoch', ':', '199', 'iter', ':', '12', 'loss:', '0.93220', 'dice:', '0.24452']
# ['epoch', ':', '199', 'iter', ':', '12', 'loss:', '0.75162', 'dice:', '0.43179']
# ['epoch', ':', '199', 'iter', ':', '12', 'loss:', '0.82183', 'dice:', '0.34028']
# ['epoch', ':', '199', 'iter', ':', '12', 'loss:', '0.65191', 'dice:', '0.49830']
# ['epoch', ':', '200', 'iter', ':', '0', 'loss:', '0.64825', 'dice:', '0.49067']
# ['epoch', ':', '200', 'iter', ':', '0', 'loss:', '0.64078', 'dice:', '0.49019']
# ['epoch', ':', '200', 'iter', ':', '0', 'loss:', '0.68910', 'dice:', '0.44503']
# ['epoch', ':', '200', 'iter', ':', '0', 'loss:', '0.61461', 'dice:', '0.54024']
# ['epoch', ':', '200', 'iter', ':', '1', 'loss:', '0.68337', 'dice:', '0.44492']
# ['epoch', ':', '200', 'iter', ':', '1', 'loss:', '0.53332', 'dice:', '0.60350']
# ['epoch', ':', '200', 'iter', ':', '1', 'loss:', '0.67754', 'dice:', '0.47139']
# ['epoch', ':', '200', 'iter', ':', '1', 'loss:', '0.64759', 'dice:', '0.48298']
# ['epoch', ':', '200', 'iter', ':', '2', 'loss:', '0.75067', 'dice:', '0.39452']
# ['epoch', ':', '200', 'iter', ':', '2', 'loss:', '0.60567', 'dice:', '0.53459']
# ['epoch', ':', '200', 'iter', ':', '2', 'loss:', '0.62095', 'dice:', '0.53011']
# ['epoch', ':', '200', 'iter', ':', '2', 'loss:', '0.72621', 'dice:', '0.40542']
# ['epoch', ':', '200', 'iter', ':', '3', 'loss:', '0.53932', 'dice:', '0.59510']
# ['epoch', ':', '200', 'iter', ':', '3', 'loss:', '0.68808', 'dice:', '0.44750']
# ['epoch', ':', '200', 'iter', ':', '3', 'loss:', '0.71344', 'dice:', '0.42472']
# ['epoch', ':', '200', 'iter', ':', '3', 'loss:', '0.69444', 'dice:', '0.43709']
# ['epoch', ':', '200', 'iter', ':', '4', 'loss:', '0.66896', 'dice:', '0.46129']
# ['epoch', ':', '200', 'iter', ':', '4', 'loss:', '0.72397', 'dice:', '0.41785']
# ['epoch', ':', '200', 'iter', ':', '4', 'loss:', '0.59004', 'dice:', '0.54782']
# ['epoch', ':', '200', 'iter', ':', '4', 'loss:', '0.62363', 'dice:', '0.50494']
# ['epoch', ':', '200', 'iter', ':', '5', 'loss:', '0.70785', 'dice:', '0.41768']
# ['epoch', ':', '200', 'iter', ':', '5', 'loss:', '0.67724', 'dice:', '0.45891']
# ['epoch', ':', '200', 'iter', ':', '5', 'loss:', '0.63514', 'dice:', '0.50895']
# ['epoch', ':', '200', 'iter', ':', '5', 'loss:', '0.68610', 'dice:', '0.45541']
# ['epoch', ':', '200', 'iter', ':', '6', 'loss:', '0.71457', 'dice:', '0.41941']
# ['epoch', ':', '200', 'iter', ':', '6', 'loss:', '0.64597', 'dice:', '0.49292']
# ['epoch', ':', '200', 'iter', ':', '6', 'loss:', '0.61689', 'dice:', '0.53230']
# ['epoch', ':', '200', 'iter', ':', '6', 'loss:', '0.61868', 'dice:', '0.53097']
# ['epoch', ':', '200', 'iter', ':', '7', 'loss:', '0.72696', 'dice:', '0.40559']
# ['epoch', ':', '200', 'iter', ':', '7', 'loss:', '0.64213', 'dice:', '0.50136']
# ['epoch', ':', '200', 'iter', ':', '7', 'loss:', '0.63644', 'dice:', '0.48860']
# ['epoch', ':', '200', 'iter', ':', '7', 'loss:', '0.61064', 'dice:', '0.52795']
# ['epoch', ':', '200', 'iter', ':', '8', 'loss:', '0.62346', 'dice:', '0.52377']
# ['epoch', ':', '200', 'iter', ':', '8', 'loss:', '0.77236', 'dice:', '0.34883']
# ['epoch', ':', '200', 'iter', ':', '8', 'loss:', '0.72281', 'dice:', '0.41069']
# ['epoch', ':', '200', 'iter', ':', '8', 'loss:', '0.68248', 'dice:', '0.45059']
# ['epoch', ':', '200', 'iter', ':', '9', 'loss:', '0.64896', 'dice:', '0.52644']
# ['epoch', ':', '200', 'iter', ':', '9', 'loss:', '0.67135', 'dice:', '0.46876']
# ['epoch', ':', '200', 'iter', ':', '9', 'loss:', '0.63802', 'dice:', '0.48488']
# ['epoch', ':', '200', 'iter', ':', '9', 'loss:', '0.71913', 'dice:', '0.40935']
# ['epoch', ':', '200', 'iter', ':', '10', 'loss:', '0.73571', 'dice:', '0.39644']
# ['epoch', ':', '200', 'iter', ':', '10', 'loss:', '0.72085', 'dice:', '0.41712']
# ['epoch', ':', '200', 'iter', ':', '10', 'loss:', '0.66084', 'dice:', '0.46258']
# ['epoch', ':', '200', 'iter', ':', '10', 'loss:', '0.66139', 'dice:', '0.48991']
# ['epoch', ':', '200', 'iter', ':', '11', 'loss:', '0.67954', 'dice:', '0.45958']
# ['epoch', ':', '200', 'iter', ':', '11', 'loss:', '0.69915', 'dice:', '0.44694']
# ['epoch', ':', '200', 'iter', ':', '11', 'loss:', '0.63177', 'dice:', '0.49229']
# ['epoch', ':', '200', 'iter', ':', '11', 'loss:', '0.64857', 'dice:', '0.48835']
# ['epoch', ':', '200', 'iter', ':', '12', 'loss:', '0.55132', 'dice:', '0.59970']
# ['epoch', ':', '200', 'iter', ':', '12', 'loss:', '0.56329', 'dice:', '0.58882']
# ['epoch', ':', '200', 'iter', ':', '12', 'loss:', '0.48920', 'dice:', '0.64908']
# ['epoch', ':', '200', 'iter', ':', '12', 'loss:', '0.57023', 'dice:', '0.58084']
# ['epoch', ':', '201', 'iter', ':', '0', 'loss:', '0.73011', 'dice:', '0.40101']
# ['epoch', ':', '201', 'iter', ':', '0', 'loss:', '0.68820', 'dice:', '0.45336']
# ['epoch', ':', '201', 'iter', ':', '0', 'loss:', '0.68720', 'dice:', '0.44861']
# ['epoch', ':', '201', 'iter', ':', '0', 'loss:', '0.63576', 'dice:', '0.51037']
# ['epoch', ':', '201', 'iter', ':', '1', 'loss:', '0.68712', 'dice:', '0.43800']
# ['epoch', ':', '201', 'iter', ':', '1', 'loss:', '0.69656', 'dice:', '0.43888']
# ['epoch', ':', '201', 'iter', ':', '1', 'loss:', '0.66670', 'dice:', '0.47139']
# ['epoch', ':', '201', 'iter', ':', '1', 'loss:', '0.65021', 'dice:', '0.49524']
# ['epoch', ':', '201', 'iter', ':', '2', 'loss:', '0.59387', 'dice:', '0.55402']
# ['epoch', ':', '201', 'iter', ':', '2', 'loss:', '0.62369', 'dice:', '0.51460']
# ['epoch', ':', '201', 'iter', ':', '2', 'loss:', '0.66653', 'dice:', '0.46672']
# ['epoch', ':', '201', 'iter', ':', '2', 'loss:', '0.77723', 'dice:', '0.36863']
# ['epoch', ':', '201', 'iter', ':', '3', 'loss:', '0.58759', 'dice:', '0.55793']
# ['epoch', ':', '201', 'iter', ':', '3', 'loss:', '0.77910', 'dice:', '0.35694']
# ['epoch', ':', '201', 'iter', ':', '3', 'loss:', '0.65412', 'dice:', '0.47712']
# ['epoch', ':', '201', 'iter', ':', '3', 'loss:', '0.56169', 'dice:', '0.57361']
# ['epoch', ':', '201', 'iter', ':', '4', 'loss:', '0.69250', 'dice:', '0.43991']
# ['epoch', ':', '201', 'iter', ':', '4', 'loss:', '0.66660', 'dice:', '0.46087']
# ['epoch', ':', '201', 'iter', ':', '4', 'loss:', '0.58416', 'dice:', '0.55519']
# ['epoch', ':', '201', 'iter', ':', '4', 'loss:', '0.72405', 'dice:', '0.41700']
# ['epoch', ':', '201', 'iter', ':', '5', 'loss:', '0.60368', 'dice:', '0.53250']
# ['epoch', ':', '201', 'iter', ':', '5', 'loss:', '0.69728', 'dice:', '0.44800']
# ['epoch', ':', '201', 'iter', ':', '5', 'loss:', '0.57850', 'dice:', '0.56352']
# ['epoch', ':', '201', 'iter', ':', '5', 'loss:', '0.64206', 'dice:', '0.49772']
# ['epoch', ':', '201', 'iter', ':', '6', 'loss:', '0.69225', 'dice:', '0.44072']
# ['epoch', ':', '201', 'iter', ':', '6', 'loss:', '0.64300', 'dice:', '0.49691']
# ['epoch', ':', '201', 'iter', ':', '6', 'loss:', '0.66280', 'dice:', '0.47093']
# ['epoch', ':', '201', 'iter', ':', '6', 'loss:', '0.60341', 'dice:', '0.53540']

# %%
logs_ = {
    'epochs' : [],
    'iterations' : [],
    'losses' : [],
    'dices' : []
}

for line in lines:
    
    dice = line.split()[-1]
    loss = line.split()[-3]
    iter = line.split()[-5]
    epoch = line.split()[-8]
    
    logs_["dices"].append(dice)
    logs_["losses"].append(loss)
    logs_["iterations"].append(iter)
    logs_["epochs"].append(epoch)

# %%
losses = [float(i) for i in logs_['losses']]
dices =  [float(i) for i in logs_['dices']]

# %%
# Plot loss over time
plt.figure(figsize=(20, 12))
plt.plot(losses, marker='o', linestyle='-')
plt.title('Loss over Time')
plt.xlabel('Iterations')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
# Plot loss over time
plt.figure(figsize=(20, 12))
plt.plot(dices, marker='o', linestyle='-')
plt.title('Loss over Time')
plt.xlabel('Iterations')
plt.ylabel('dice')
# Out:
# Text(0, 0.5, 'dice')
